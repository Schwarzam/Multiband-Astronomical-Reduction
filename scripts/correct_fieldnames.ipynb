# %%
import pandas as pd
import os
from os.path import join
import psycopg2

from astropy.io import fits
from astropy.coordinates import SkyCoord
from astropy import units as u

# %%
def update_data(conn_str, table, set_columns, set_values, condition=None, condition_values=None):
    """
    Update rows in a PostgreSQL table.

    Parameters:
    - conn_str: PostgreSQL connection string.
    - table: Name of the table you want to update.
    - set_columns: Columns that you want to update.
    - set_values: Values corresponding to the columns you want to update.
    - condition: (Optional) Condition for the rows you want to update.
    - condition_values: (Optional) Values for the conditions.
    
    Returns:
    - Number of updated rows.
    """
    # Form the SQL update statement
    set_clause = ', '.join([f"{col} = %s" for col in set_columns])
    query = f"UPDATE {table} SET {set_clause}"
    if condition:
        query += f" WHERE {condition}"
    
    # Combine the values
    values = set_values
    if condition_values:
        values += condition_values
    
    print(query, values)
    # with psycopg2.connect(conn_str) as conn:
    #     with conn.cursor() as cursor:
    #         cursor.execute(query, values)
    #         conn.commit()
    #         return cursor.rowcount

def delete_data(conn_str, table, condition=None, condition_values=None):
    """
    Delete rows from a PostgreSQL table.

    Parameters:
    - conn_str: PostgreSQL connection string.
    - table: Name of the table from which you want to delete rows.
    - condition: (Optional) Condition to specify which rows to delete.
    - condition_values: (Optional) Values for the condition.
    
    Returns:
    - Number of deleted rows.
    """
    
    # Form the SQL DELETE statement
    query = f"DELETE FROM {table}"
    if condition:
        query += f" WHERE {condition}"
    
    with psycopg2.connect(conn_str) as conn:
        with conn.cursor() as cursor:
            cursor.execute(query, condition_values)
            conn.commit()
            return cursor.rowcount

# Example usage:
conn_str = "dbname='mydatabase' user='username' host='localhost' password='password' port='5432'"

# This will delete rows from the 'users' table where 'id' is 1
deleted_rows = delete_data(conn_str, "users", "id = %s", [1])
print(f"{deleted_rows} row(s) deleted.")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[20], line 63
#      60 conn_str = "dbname='mydatabase' user='username' host='localhost' password='password' port='5432'"
#      62 # This will delete rows from the 'users' table where 'id' is 1
# ---> 63 deleted_rows = delete_data(conn_str, "users", "id = %s", [1])
#      64 print(f"{deleted_rows} row(s) deleted.")
#
# Cell In[20], line 53, in delete_data(conn_str, table, condition, condition_values)
#      50 if condition:
#      51     query += f" WHERE {condition}"
# ---> 53 with psycopg2.connect(conn_str) as conn:
#      54     with conn.cursor() as cursor:
#      55         cursor.execute(query, condition_values)
#
# File ~/.local/lib/python3.10/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#     124     conn.cursor_factory = cursor_factory
#
# OperationalError: connection to server at "localhost" (127.0.0.1), port 5432 failed: FATAL:  password authentication failed for user "username"
# connection to server at "localhost" (127.0.0.1), port 5432 failed: FATAL:  password authentication failed for user "username"

# %%
bands = ["R", "G", "I", "Z", "U", "F378", "F395", "F410", "F430", "F515", "F660", "F861"]

# %%
def get_filename(field, band):
    return f"{field}_{band}_swp.fits.fz"

# %%
def write_log(text):
    open("log.txt", "a").write(text + "\n")

def write_changes(text):
    open("changes.txt", "a").write(text + "\n")

# %%
conn = psycopg2.connect(database="mar", user="postgres", password="password", host="127.0.0.1", port="5432")
cursor = conn.cursor()

# %%
def querydb(query):
    # Query data
    return pd.read_sql(query, conn)

# %%
queryres = querydb("SELECT * from files_individualfile WHERE file_name LIKE '%CN%' ")
# Out:
# /tmp/ipykernel_1644840/2301257939.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(query, conn)

# %%
queryres
# Out:
#            id                          obsDate   field file_type  exptime  \
# 0      127221 2019-11-16 05:13:16.914000+00:00  NGC104       SCI    120.0
# 1      127212 2019-11-16 04:47:08.612000+00:00  NGC104       SCI     30.0
# 2      127219 2019-11-16 05:16:18.822000+00:00  NGC104       SCI      5.0
# 3      127211 2019-11-16 04:56:27.792000+00:00  NGC104       SCI    150.0
# 4      127222 2019-11-16 05:09:02.450000+00:00  NGC104       SCI    150.0
# ...       ...                              ...     ...       ...      ...
# 26467  124564 2019-11-07 06:13:50.712000+00:00  NGC104       SCI     60.0
# 26468  124582 2019-11-07 06:17:12.134000+00:00  NGC104       SCI     30.0
# 26469  124591 2019-11-07 06:37:08.593000+00:00  NGC104       SCI     30.0
# 26470  127220 2019-11-16 05:12:27.932000+00:00  NGC104       SCI     10.0
# 26471  127216 2019-11-16 05:05:17.193000+00:00  NGC104       SCI    120.0
#
#        band                  file_name  \
# 0         R  CN2018A76-20191116-021541
# 1         U  CN2018A76-20191116-014801
# 2         I  CN2018A76-20191116-021647
# 3      F395  CN2018A76-20191116-015921
# 4         G  CN2018A76-20191116-021156
# ...     ...                        ...
# 26467  F660  CN2018A76-20191107-031514
# 26468     U  CN2018A76-20191107-031806
# 26469     U  CN2018A76-20191107-033802
# 26470     R  CN2018A76-20191116-021302
# 26471  F515  CN2018A76-20191116-020741
#
#                                         file_path ovfile ovthumb  ...  \
# 0      20191115/CN2018A76-20191116-021541.fits.fz   None    None  ...
# 1      20191115/CN2018A76-20191116-014801.fits.fz   None    None  ...
# 2      20191115/CN2018A76-20191116-021647.fits.fz   None    None  ...
# 3      20191115/CN2018A76-20191116-015921.fits.fz   None    None  ...
# 4      20191115/CN2018A76-20191116-021156.fits.fz   None    None  ...
# ...                                           ...    ...     ...  ...
# 26467  20191106/CN2018A76-20191107-031514.fits.fz   None    None  ...
# 26468  20191106/CN2018A76-20191107-031806.fits.fz   None    None  ...
# 26469  20191106/CN2018A76-20191107-033802.fits.fz   None    None  ...
# 26470  20191115/CN2018A76-20191116-021302.fits.fz   None    None  ...
# 26471  20191115/CN2018A76-20191116-020741.fits.fz   None    None  ...
#
#       comments  status  isvalid  processed_id  sci_id  superflat_id  \
# 0         None       0        1           NaN     NaN           NaN
# 1         None       0        1           NaN     NaN           NaN
# 2         None       0        1           NaN     NaN           NaN
# 3         None       0        1           NaN     NaN           NaN
# 4         None       0        1           NaN     NaN           NaN
# ...        ...     ...      ...           ...     ...           ...
# 26467     None       0        1           NaN     NaN           NaN
# 26468     None       0        1           NaN     NaN           NaN
# 26469     None       0        1           NaN     NaN           NaN
# 26470     None       0        1           NaN     NaN           NaN
# 26471     None       0        1           NaN     NaN           NaN
#
#       raw_sci_id moonmean crval1  crval2
# 0            NaN      NaN    NaN     NaN
# 1            NaN      NaN    NaN     NaN
# 2            NaN      NaN    NaN     NaN
# 3            NaN      NaN    NaN     NaN
# 4            NaN      NaN    NaN     NaN
# ...          ...      ...    ...     ...
# 26467        NaN      NaN    NaN     NaN
# 26468        NaN      NaN    NaN     NaN
# 26469        NaN      NaN    NaN     NaN
# 26470        NaN      NaN    NaN     NaN
# 26471        NaN      NaN    NaN     NaN
#
# [26472 rows x 28 columns]

# %%
df = pd.read_csv("ref_table_chances.csv")
raw_files_path = "../reductionmedia/TILES/"
raw_files = "../reductionmedia"

coords_table = SkyCoord(ra=df['RA']*u.degree, dec=df['DEC']*u.degree, frame='icrs')

def find_closest_row(ra_input, dec_input):
    input_coord = SkyCoord(ra=ra_input*u.degree, dec=dec_input*u.degree, frame='icrs')
    idx, d2d, d3d = input_coord.match_to_catalog_sky(coords_table)
    if d2d > 700.0 * u.arcsec:
        return None
    return df.iloc[idx]

# %%
open("log.txt", "w")

for key, value in df.iterrows():
    field = value["Field"]
    write_log(f"Checking field {field}")
    
    folder_path = join(raw_files_path, value["Field"])
    queryres[(queryres["field"] == field) & (queryres["band"] == "R")]

    for band in bands:
        filedb = queryres[(queryres["field"] == field) & (queryres["band"] == "R")]
        filename = get_filename(field, band)
        filepath = join(folder_path, filename)

        if len(filedb) == 0:
            write_log(f"Not found {filename}")
    
        else:
            write_log(filename + " file_exists:" + str(os.path.exists(filepath)))
            if os.path.exists(filepath):
                header = fits.getheader(filepath, 1)
                print(header)
                ra, dec = float(header['CRVAL1']), float(header['CRVAL2'])
                row = find_closest_row(ra, dec)
                
                print(ra, dec, field)
                print(row)
        
    break
# Out:
# SIMPLE  =                    T / This is a FITS file                            BITPIX  =                  -32                                                  NAXIS   =                    2                                                  NAXIS1  =                11000 / Number of pixels along this axis               NAXIS2  =                11000 / Number of pixels along this axis               EQUINOX =        2000.00000000 / Mean equinox                                   MJD-OBS =       59222.34722222 / Modified Julian date at start                  RADESYS = 'ICRS    '           / Astrometric system                             CTYPE1  = 'RA---TAN'           / WCS projection type for this axis              CUNIT1  = 'deg     '           / Axis unit                                      CRVAL1  =   9.042540856542E+01 / World coordinate on this axis                  CRPIX1  =   5.500500000000E+03 / Reference pixel on this axis                   CD1_1   =  -1.527777777778E-04 / Linear projection matrix                       CD1_2   =   0.000000000000E+00 / Linear projection matrix                       CTYPE2  = 'DEC--TAN'           / WCS projection type for this axis              CUNIT2  = 'deg     '           / Axis unit                                      CRVAL2  =  -3.998499061405E+01 / World coordinate on this axis                  CRPIX2  =   5.500500000000E+03 / Reference pixel on this axis                   CD2_1   =   0.000000000000E+00 / Linear projection matrix                       CD2_2   =   1.527777777778E-04 / Linear projection matrix                       EXPTIME =   1.200000000000E+02 / Maximum equivalent exposure time (s)           GAIN    =   2.435990885304E+02 / Maximum equivalent gain (e-/ADU)               SATURATE=   1.607245983862E+03 / Saturation Level (ADU)                         COMMENT                                                                         SOFTNAME= 'SWarp   '           / The software that processed those data         SOFTVERS= '2.41.5  '           / Version of the software                        SOFTDATE= '2023-07-10'         / Release date of the software                   SOFTAUTH= '2010-2012 IAP/CNRS/UPMC' / Maintainer of the software                SOFTINST= 'IAP  http://www.iap.fr' / Institute                                  COMMENT                                                                         AUTHOR  = 'unknown '           / Who ran the software                           ORIGIN  = '569fafe5e8dd'       / Where it was done                              DATE    = '2023-08-09T16:34:17' / When it was started (GMT)                     COMBINET= 'WEIGHTED'           / COMBINE_TYPE config parameter for SWarp        COMMENT                                                                         COMMENT  Propagated FITS keywords                                               AIRMASS =   1.049303097767E+00 / air mass at the end of observation             TELESCOP= 'T80     '           / Telescope Model                                INSTRUME= 'T80Cam  '           / Custom. Name of instrument                     FILTER  = 'R       '           / Filter used for this observation               COMMENT                                                                         COMMENT  Axis-dependent config parameters                                       RESAMPT1= 'LANCZOS3'           / RESAMPLING_TYPE config parameter               CENTERT1= 'MANUAL  '           / CENTER_TYPE config parameter                   PSCALET1= 'MANUAL  '           / PIXELSCALE_TYPE config parameter               RESAMPT2= 'LANCZOS3'           / RESAMPLING_TYPE config parameter               CENTERT2= 'MANUAL  '           / CENTER_TYPE config parameter                   PSCALET2= 'MANUAL  '           / PIXELSCALE_TYPE config parameter               HIERARCH INSTRUMENT = 'T80S    '                                                PIXSCALE=                 0.55                                                   ...
# 90.42540856542 -39.98499061405 A3376_001
# Unnamed: 0            0
# Field         A3376_001
# RA               90.425
# DEC             -39.985
# Name: 0, dtype: object
# SIMPLE  =                    T / This is a FITS file                            BITPIX  =                  -32                                                  NAXIS   =                    2                                                  NAXIS1  =                11000 / Number of pixels along this axis               NAXIS2  =                11000 / Number of pixels along this axis               EQUINOX =        2000.00000000 / Mean equinox                                   MJD-OBS =       59222.34513889 / Modified Julian date at start                  RADESYS = 'ICRS    '           / Astrometric system                             CTYPE1  = 'RA---TAN'           / WCS projection type for this axis              CUNIT1  = 'deg     '           / Axis unit                                      CRVAL1  =   9.042540856542E+01 / World coordinate on this axis                  CRPIX1  =   5.500500000000E+03 / Reference pixel on this axis                   CD1_1   =  -1.527777777778E-04 / Linear projection matrix                       CD1_2   =   0.000000000000E+00 / Linear projection matrix                       CTYPE2  = 'DEC--TAN'           / WCS projection type for this axis              CUNIT2  = 'deg     '           / Axis unit                                      CRVAL2  =  -3.998499061405E+01 / World coordinate on this axis                  CRPIX2  =   5.500500000000E+03 / Reference pixel on this axis                   CD2_1   =   0.000000000000E+00 / Linear projection matrix                       CD2_2   =   1.527777777778E-04 / Linear projection matrix                       EXPTIME =   9.900000000000E+01 / Maximum equivalent exposure time (s)           GAIN    =   2.009697349544E+02 / Maximum equivalent gain (e-/ADU)               SATURATE=   1.947924449862E+03 / Saturation Level (ADU)                         COMMENT                                                                         SOFTNAME= 'SWarp   '           / The software that processed those data         SOFTVERS= '2.41.5  '           / Version of the software                        SOFTDATE= '2023-07-10'         / Release date of the software                   SOFTAUTH= '2010-2012 IAP/CNRS/UPMC' / Maintainer of the software                SOFTINST= 'IAP  http://www.iap.fr' / Institute                                  COMMENT                                                                         AUTHOR  = 'unknown '           / Who ran the software                           ORIGIN  = '569fafe5e8dd'       / Where it was done                              DATE    = '2023-08-08T11:47:28' / When it was started (GMT)                     COMBINET= 'WEIGHTED'           / COMBINE_TYPE config parameter for SWarp        COMMENT                                                                         COMMENT  Propagated FITS keywords                                               AIRMASS =   1.054141255481E+00 / air mass at the end of observation             TELESCOP= 'T80     '           / Telescope Model                                INSTRUME= 'T80Cam  '           / Custom. Name of instrument                     FILTER  = 'G       '           / Filter used for this observation               COMMENT                                                                         COMMENT  Axis-dependent config parameters                                       RESAMPT1= 'LANCZOS3'           / RESAMPLING_TYPE config parameter               CENTERT1= 'MANUAL  '           / CENTER_TYPE config parameter                   PSCALET1= 'MANUAL  '           / PIXELSCALE_TYPE config parameter               RESAMPT2= 'LANCZOS3'           / RESAMPLING_TYPE config parameter               CENTERT2= 'MANUAL  '           / CENTER_TYPE config parameter                   PSCALET2= 'MANUAL  '           / PIXELSCALE_TYPE config parameter               HIERARCH INSTRUMENT = 'T80S    '                                                PIXSCALE=                 0.55                                                   ...
# 90.42540856542 -39.98499061405 A3376_001
# Unnamed: 0            0
# Field         A3376_001
# RA               90.425
# DEC             -39.985
# Name: 0, dtype: object
# SIMPLE  =                    T / This is a FITS file                            BITPIX  =                  -32                                                  NAXIS   =                    2                                                  NAXIS1  =                11000 / Number of pixels along this axis               NAXIS2  =                11000 / Number of pixels along this axis               EQUINOX =        2000.00000000 / Mean equinox                                   MJD-OBS =       59222.35000000 / Modified Julian date at start                  RADESYS = 'ICRS    '           / Astrometric system                             CTYPE1  = 'RA---TAN'           / WCS projection type for this axis              CUNIT1  = 'deg     '           / Axis unit                                      CRVAL1  =   9.042540856542E+01 / World coordinate on this axis                  CRPIX1  =   5.500500000000E+03 / Reference pixel on this axis                   CD1_1   =  -1.527777777778E-04 / Linear projection matrix                       CD1_2   =   0.000000000000E+00 / Linear projection matrix                       CTYPE2  = 'DEC--TAN'           / WCS projection type for this axis              CUNIT2  = 'deg     '           / Axis unit                                      CRVAL2  =  -3.998499061405E+01 / World coordinate on this axis                  CRPIX2  =   5.500500000000E+03 / Reference pixel on this axis                   CD2_1   =   0.000000000000E+00 / Linear projection matrix                       CD2_2   =   1.527777777778E-04 / Linear projection matrix                       EXPTIME =   1.380000000000E+02 / Maximum equivalent exposure time (s)           GAIN    =   2.801341880304E+02 / Maximum equivalent gain (e-/ADU)               SATURATE=   1.397640413362E+03 / Saturation Level (ADU)                         COMMENT                                                                         SOFTNAME= 'SWarp   '           / The software that processed those data         SOFTVERS= '2.41.5  '           / Version of the software                        SOFTDATE= '2023-07-10'         / Release date of the software                   SOFTAUTH= '2010-2012 IAP/CNRS/UPMC' / Maintainer of the software                SOFTINST= 'IAP  http://www.iap.fr' / Institute                                  COMMENT                                                                         AUTHOR  = 'unknown '           / Who ran the software                           ORIGIN  = '569fafe5e8dd'       / Where it was done                              DATE    = '2023-08-08T14:42:09' / When it was started (GMT)                     COMBINET= 'WEIGHTED'           / COMBINE_TYPE config parameter for SWarp        COMMENT                                                                         COMMENT  Propagated FITS keywords                                               AIRMASS =   1.048012634974E+00 / air mass at the end of observation             TELESCOP= 'T80     '           / Telescope Model                                INSTRUME= 'T80Cam  '           / Custom. Name of instrument                     FILTER  = 'I       '           / Filter used for this observation               COMMENT                                                                         COMMENT  Axis-dependent config parameters                                       RESAMPT1= 'LANCZOS3'           / RESAMPLING_TYPE config parameter               CENTERT1= 'MANUAL  '           / CENTER_TYPE config parameter                   PSCALET1= 'MANUAL  '           / PIXELSCALE_TYPE config parameter               RESAMPT2= 'LANCZOS3'           / RESAMPLING_TYPE config parameter               CENTERT2= 'MANUAL  '           / CENTER_TYPE config parameter                   PSCALET2= 'MANUAL  '           / PIXELSCALE_TYPE config parameter               HIERARCH INSTRUMENT = 'T80S    '                                                PIXSCALE=                 0.55                                                   ...
# 90.42540856542 -39.98499061405 A3376_001
# Unnamed: 0            0
# Field         A3376_001
# RA               90.425
# DEC             -39.985
# Name: 0, dtype: object
# SIMPLE  =                    T / This is a FITS file                            BITPIX  =                  -32                                                  NAXIS   =                    2                                                  NAXIS1  =                11000 / Number of pixels along this axis               NAXIS2  =                11000 / Number of pixels along this axis               EQUINOX =        2000.00000000 / Mean equinox                                   MJD-OBS =       59222.35277778 / Modified Julian date at start                  RADESYS = 'ICRS    '           / Astrometric system                             CTYPE1  = 'RA---TAN'           / WCS projection type for this axis              CUNIT1  = 'deg     '           / Axis unit                                      CRVAL1  =   9.042540856542E+01 / World coordinate on this axis                  CRPIX1  =   5.500500000000E+03 / Reference pixel on this axis                   CD1_1   =  -1.527777777778E-04 / Linear projection matrix                       CD1_2   =   0.000000000000E+00 / Linear projection matrix                       CTYPE2  = 'DEC--TAN'           / WCS projection type for this axis              CUNIT2  = 'deg     '           / Axis unit                                      CRVAL2  =  -3.998499061405E+01 / World coordinate on this axis                  CRPIX2  =   5.500500000000E+03 / Reference pixel on this axis                   CD2_1   =   0.000000000000E+00 / Linear projection matrix                       CD2_2   =   1.527777777778E-04 / Linear projection matrix                       EXPTIME =   1.680000000000E+02 / Maximum equivalent exposure time (s)           GAIN    =   3.410276847520E+02 / Maximum equivalent gain (e-/ADU)               SATURATE=   1.148000331509E+03 / Saturation Level (ADU)                         COMMENT                                                                         SOFTNAME= 'SWarp   '           / The software that processed those data         SOFTVERS= '2.41.5  '           / Version of the software                        SOFTDATE= '2023-07-10'         / Release date of the software                   SOFTAUTH= '2010-2012 IAP/CNRS/UPMC' / Maintainer of the software                SOFTINST= 'IAP  http://www.iap.fr' / Institute                                  COMMENT                                                                         AUTHOR  = 'unknown '           / Who ran the software                           ORIGIN  = '569fafe5e8dd'       / Where it was done                              DATE    = '2023-08-08T17:41:55' / When it was started (GMT)                     COMBINET= 'WEIGHTED'           / COMBINE_TYPE config parameter for SWarp        COMMENT                                                                         COMMENT  Propagated FITS keywords                                               AIRMASS =   1.044213991512E+00 / air mass at the end of observation             TELESCOP= 'T80     '           / Telescope Model                                INSTRUME= 'T80Cam  '           / Custom. Name of instrument                     FILTER  = 'Z       '           / Filter used for this observation               COMMENT                                                                         COMMENT  Axis-dependent config parameters                                       RESAMPT1= 'LANCZOS3'           / RESAMPLING_TYPE config parameter               CENTERT1= 'MANUAL  '           / CENTER_TYPE config parameter                   PSCALET1= 'MANUAL  '           / PIXELSCALE_TYPE config parameter               RESAMPT2= 'LANCZOS3'           / RESAMPLING_TYPE config parameter               CENTERT2= 'MANUAL  '           / CENTER_TYPE config parameter                   PSCALET2= 'MANUAL  '           / PIXELSCALE_TYPE config parameter               HIERARCH INSTRUMENT = 'T80S    '                                                PIXSCALE=                 0.55                                                   ...
# 90.42540856542 -39.98499061405 A3376_001
# Unnamed: 0            0
# Field         A3376_001
# RA               90.425
# DEC             -39.985
# Name: 0, dtype: object
# SIMPLE  =                    T / This is a FITS file                            BITPIX  =                  -32                                                  NAXIS   =                    2                                                  NAXIS1  =                11000 / Number of pixels along this axis               NAXIS2  =                11000 / Number of pixels along this axis               EQUINOX =        2000.00000000 / Mean equinox                                   MJD-OBS =       59222.31180556 / Modified Julian date at start                  RADESYS = 'ICRS    '           / Astrometric system                             CTYPE1  = 'RA---TAN'           / WCS projection type for this axis              CUNIT1  = 'deg     '           / Axis unit                                      CRVAL1  =   9.042540856542E+01 / World coordinate on this axis                  CRPIX1  =   5.500500000000E+03 / Reference pixel on this axis                   CD1_1   =  -1.527777777778E-04 / Linear projection matrix                       CD1_2   =   0.000000000000E+00 / Linear projection matrix                       CTYPE2  = 'DEC--TAN'           / WCS projection type for this axis              CUNIT2  = 'deg     '           / Axis unit                                      CRVAL2  =  -3.998499061405E+01 / World coordinate on this axis                  CRPIX2  =   5.500500000000E+03 / Reference pixel on this axis                   CD2_1   =   0.000000000000E+00 / Linear projection matrix                       CD2_2   =   1.527777777778E-04 / Linear projection matrix                       EXPTIME =   6.810000000000E+02 / Maximum equivalent exposure time (s)           GAIN    =   1.382424105801E+03 / Maximum equivalent gain (e-/ADU)               SATURATE=   2.831657912750E+02 / Saturation Level (ADU)                         COMMENT                                                                         SOFTNAME= 'SWarp   '           / The software that processed those data         SOFTVERS= '2.41.5  '           / Version of the software                        SOFTDATE= '2023-07-10'         / Release date of the software                   SOFTAUTH= '2010-2012 IAP/CNRS/UPMC' / Maintainer of the software                SOFTINST= 'IAP  http://www.iap.fr' / Institute                                  COMMENT                                                                         AUTHOR  = 'unknown '           / Who ran the software                           ORIGIN  = '569fafe5e8dd'       / Where it was done                              DATE    = '2023-08-08T20:08:17' / When it was started (GMT)                     COMBINET= 'WEIGHTED'           / COMBINE_TYPE config parameter for SWarp        COMMENT                                                                         COMMENT  Propagated FITS keywords                                               AIRMASS =   1.118517712850E+00 / air mass at the end of observation             TELESCOP= 'T80     '           / Telescope Model                                INSTRUME= 'T80Cam  '           / Custom. Name of instrument                     FILTER  = 'U       '           / Filter used for this observation               COMMENT                                                                         COMMENT  Axis-dependent config parameters                                       RESAMPT1= 'LANCZOS3'           / RESAMPLING_TYPE config parameter               CENTERT1= 'MANUAL  '           / CENTER_TYPE config parameter                   PSCALET1= 'MANUAL  '           / PIXELSCALE_TYPE config parameter               RESAMPT2= 'LANCZOS3'           / RESAMPLING_TYPE config parameter               CENTERT2= 'MANUAL  '           / CENTER_TYPE config parameter                   PSCALET2= 'MANUAL  '           / PIXELSCALE_TYPE config parameter               HIERARCH INSTRUMENT = 'T80S    '                                                PIXSCALE=                 0.55                                                   ...
# 90.42540856542 -39.98499061405 A3376_001
# Unnamed: 0            0
# Field         A3376_001
# RA               90.425
# DEC             -39.985
# Name: 0, dtype: object
# SIMPLE  =                    T / This is a FITS file                            BITPIX  =                  -32                                                  NAXIS   =                    2                                                  NAXIS1  =                11000 / Number of pixels along this axis               NAXIS2  =                11000 / Number of pixels along this axis               EQUINOX =        2000.00000000 / Mean equinox                                   MJD-OBS =       59222.32083333 / Modified Julian date at start                  RADESYS = 'ICRS    '           / Astrometric system                             CTYPE1  = 'RA---TAN'           / WCS projection type for this axis              CUNIT1  = 'deg     '           / Axis unit                                      CRVAL1  =   9.042540856542E+01 / World coordinate on this axis                  CRPIX1  =   5.500500000000E+03 / Reference pixel on this axis                   CD1_1   =  -1.527777777778E-04 / Linear projection matrix                       CD1_2   =   0.000000000000E+00 / Linear projection matrix                       CTYPE2  = 'DEC--TAN'           / WCS projection type for this axis              CUNIT2  = 'deg     '           / Axis unit                                      CRVAL2  =  -3.998499061405E+01 / World coordinate on this axis                  CRPIX2  =   5.500500000000E+03 / Reference pixel on this axis                   CD2_1   =   0.000000000000E+00 / Linear projection matrix                       CD2_2   =   1.527777777778E-04 / Linear projection matrix                       EXPTIME =   6.600000000000E+02 / Maximum equivalent exposure time (s)           GAIN    =   1.339791133599E+03 / Maximum equivalent gain (e-/ADU)               SATURATE=   2.921443758003E+02 / Saturation Level (ADU)                         COMMENT                                                                         SOFTNAME= 'SWarp   '           / The software that processed those data         SOFTVERS= '2.41.5  '           / Version of the software                        SOFTDATE= '2023-07-10'         / Release date of the software                   SOFTAUTH= '2010-2012 IAP/CNRS/UPMC' / Maintainer of the software                SOFTINST= 'IAP  http://www.iap.fr' / Institute                                  COMMENT                                                                         AUTHOR  = 'unknown '           / Who ran the software                           ORIGIN  = '569fafe5e8dd'       / Where it was done                              DATE    = '2023-08-08T22:24:17' / When it was started (GMT)                     COMBINET= 'WEIGHTED'           / COMBINE_TYPE config parameter for SWarp        COMMENT                                                                         COMMENT  Propagated FITS keywords                                               AIRMASS =   1.102937845019E+00 / air mass at the end of observation             TELESCOP= 'T80     '           / Telescope Model                                INSTRUME= 'T80Cam  '           / Custom. Name of instrument                     FILTER  = 'F378    '           / Filter used for this observation               COMMENT                                                                         COMMENT  Axis-dependent config parameters                                       RESAMPT1= 'LANCZOS3'           / RESAMPLING_TYPE config parameter               CENTERT1= 'MANUAL  '           / CENTER_TYPE config parameter                   PSCALET1= 'MANUAL  '           / PIXELSCALE_TYPE config parameter               RESAMPT2= 'LANCZOS3'           / RESAMPLING_TYPE config parameter               CENTERT2= 'MANUAL  '           / CENTER_TYPE config parameter                   PSCALET2= 'MANUAL  '           / PIXELSCALE_TYPE config parameter               HIERARCH INSTRUMENT = 'T80S    '                                                PIXSCALE=                 0.55                                                   ...
# 90.42540856542 -39.98499061405 A3376_001
# Unnamed: 0            0
# Field         A3376_001
# RA               90.425
# DEC             -39.985
# Name: 0, dtype: object
# SIMPLE  =                    T / This is a FITS file                            BITPIX  =                  -32                                                  NAXIS   =                    2                                                  NAXIS1  =                11000 / Number of pixels along this axis               NAXIS2  =                11000 / Number of pixels along this axis               EQUINOX =        2000.00000000 / Mean equinox                                   MJD-OBS =       59222.32986111 / Modified Julian date at start                  RADESYS = 'ICRS    '           / Astrometric system                             CTYPE1  = 'RA---TAN'           / WCS projection type for this axis              CUNIT1  = 'deg     '           / Axis unit                                      CRVAL1  =   9.042540856542E+01 / World coordinate on this axis                  CRPIX1  =   5.500500000000E+03 / Reference pixel on this axis                   CD1_1   =  -1.527777777778E-04 / Linear projection matrix                       CD1_2   =   0.000000000000E+00 / Linear projection matrix                       CTYPE2  = 'DEC--TAN'           / WCS projection type for this axis              CUNIT2  = 'deg     '           / Axis unit                                      CRVAL2  =  -3.998499061405E+01 / World coordinate on this axis                  CRPIX2  =   5.500500000000E+03 / Reference pixel on this axis                   CD2_1   =   0.000000000000E+00 / Linear projection matrix                       CD2_2   =   1.527777777778E-04 / Linear projection matrix                       EXPTIME =   3.540000000000E+02 / Maximum equivalent exposure time (s)           GAIN    =   7.186197095998E+02 / Maximum equivalent gain (e-/ADU)               SATURATE=   5.446986218812E+02 / Saturation Level (ADU)                         COMMENT                                                                         SOFTNAME= 'SWarp   '           / The software that processed those data         SOFTVERS= '2.41.5  '           / Version of the software                        SOFTDATE= '2023-07-10'         / Release date of the software                   SOFTAUTH= '2010-2012 IAP/CNRS/UPMC' / Maintainer of the software                SOFTINST= 'IAP  http://www.iap.fr' / Institute                                  COMMENT                                                                         AUTHOR  = 'unknown '           / Who ran the software                           ORIGIN  = '569fafe5e8dd'       / Where it was done                              DATE    = '2023-08-09T00:29:50' / When it was started (GMT)                     COMBINET= 'WEIGHTED'           / COMBINE_TYPE config parameter for SWarp        COMMENT                                                                         COMMENT  Propagated FITS keywords                                               AIRMASS =   1.079243603931E+00 / air mass at the end of observation             TELESCOP= 'T80     '           / Telescope Model                                INSTRUME= 'T80Cam  '           / Custom. Name of instrument                     FILTER  = 'F395    '           / Filter used for this observation               COMMENT                                                                         COMMENT  Axis-dependent config parameters                                       RESAMPT1= 'LANCZOS3'           / RESAMPLING_TYPE config parameter               CENTERT1= 'MANUAL  '           / CENTER_TYPE config parameter                   PSCALET1= 'MANUAL  '           / PIXELSCALE_TYPE config parameter               RESAMPT2= 'LANCZOS3'           / RESAMPLING_TYPE config parameter               CENTERT2= 'MANUAL  '           / CENTER_TYPE config parameter                   PSCALET2= 'MANUAL  '           / PIXELSCALE_TYPE config parameter               HIERARCH INSTRUMENT = 'T80S    '                                                PIXSCALE=                 0.55                                                   ...
# 90.42540856542 -39.98499061405 A3376_001
# Unnamed: 0            0
# Field         A3376_001
# RA               90.425
# DEC             -39.985
# Name: 0, dtype: object
# SIMPLE  =                    T / This is a FITS file                            BITPIX  =                  -32                                                  NAXIS   =                    2                                                  NAXIS1  =                11000 / Number of pixels along this axis               NAXIS2  =                11000 / Number of pixels along this axis               EQUINOX =        2000.00000000 / Mean equinox                                   MJD-OBS =       59222.33541667 / Modified Julian date at start                  RADESYS = 'ICRS    '           / Astrometric system                             CTYPE1  = 'RA---TAN'           / WCS projection type for this axis              CUNIT1  = 'deg     '           / Axis unit                                      CRVAL1  =   9.042540856542E+01 / World coordinate on this axis                  CRPIX1  =   5.500500000000E+03 / Reference pixel on this axis                   CD1_1   =  -1.527777777778E-04 / Linear projection matrix                       CD1_2   =   0.000000000000E+00 / Linear projection matrix                       CTYPE2  = 'DEC--TAN'           / WCS projection type for this axis              CUNIT2  = 'deg     '           / Axis unit                                      CRVAL2  =  -3.998499061405E+01 / World coordinate on this axis                  CRPIX2  =   5.500500000000E+03 / Reference pixel on this axis                   CD2_1   =   0.000000000000E+00 / Linear projection matrix                       CD2_2   =   1.527777777778E-04 / Linear projection matrix                       EXPTIME =   1.770000000000E+02 / Maximum equivalent exposure time (s)           GAIN    =   3.593081732325E+02 / Maximum equivalent gain (e-/ADU)               SATURATE=   1.089442798854E+03 / Saturation Level (ADU)                         COMMENT                                                                         SOFTNAME= 'SWarp   '           / The software that processed those data         SOFTVERS= '2.41.5  '           / Version of the software                        SOFTDATE= '2023-07-10'         / Release date of the software                   SOFTAUTH= '2010-2012 IAP/CNRS/UPMC' / Maintainer of the software                SOFTINST= 'IAP  http://www.iap.fr' / Institute                                  COMMENT                                                                         AUTHOR  = 'unknown '           / Who ran the software                           ORIGIN  = '569fafe5e8dd'       / Where it was done                              DATE    = '2023-08-09T02:41:59' / When it was started (GMT)                     COMBINET= 'WEIGHTED'           / COMBINE_TYPE config parameter for SWarp        COMMENT                                                                         COMMENT  Propagated FITS keywords                                               AIRMASS =   1.072348320546E+00 / air mass at the end of observation             TELESCOP= 'T80     '           / Telescope Model                                INSTRUME= 'T80Cam  '           / Custom. Name of instrument                     FILTER  = 'F410    '           / Filter used for this observation               COMMENT                                                                         COMMENT  Axis-dependent config parameters                                       RESAMPT1= 'LANCZOS3'           / RESAMPLING_TYPE config parameter               CENTERT1= 'MANUAL  '           / CENTER_TYPE config parameter                   PSCALET1= 'MANUAL  '           / PIXELSCALE_TYPE config parameter               RESAMPT2= 'LANCZOS3'           / RESAMPLING_TYPE config parameter               CENTERT2= 'MANUAL  '           / CENTER_TYPE config parameter                   PSCALET2= 'MANUAL  '           / PIXELSCALE_TYPE config parameter               HIERARCH INSTRUMENT = 'T80S    '                                                PIXSCALE=                 0.55                                                   ...
# 90.42540856542 -39.98499061405 A3376_001
# Unnamed: 0            0
# Field         A3376_001
# RA               90.425
# DEC             -39.985
# Name: 0, dtype: object
# SIMPLE  =                    T / This is a FITS file                            BITPIX  =                  -32                                                  NAXIS   =                    2                                                  NAXIS1  =                11000 / Number of pixels along this axis               NAXIS2  =                11000 / Number of pixels along this axis               EQUINOX =        2000.00000000 / Mean equinox                                   MJD-OBS =       59222.33819444 / Modified Julian date at start                  RADESYS = 'ICRS    '           / Astrometric system                             CTYPE1  = 'RA---TAN'           / WCS projection type for this axis              CUNIT1  = 'deg     '           / Axis unit                                      CRVAL1  =   9.042540856542E+01 / World coordinate on this axis                  CRPIX1  =   5.500500000000E+03 / Reference pixel on this axis                   CD1_1   =  -1.527777777778E-04 / Linear projection matrix                       CD1_2   =   0.000000000000E+00 / Linear projection matrix                       CTYPE2  = 'DEC--TAN'           / WCS projection type for this axis              CUNIT2  = 'deg     '           / Axis unit                                      CRVAL2  =  -3.998499061405E+01 / World coordinate on this axis                  CRPIX2  =   5.500500000000E+03 / Reference pixel on this axis                   CD2_1   =   0.000000000000E+00 / Linear projection matrix                       CD2_2   =   1.527777777778E-04 / Linear projection matrix                       EXPTIME =   1.710000000000E+02 / Maximum equivalent exposure time (s)           GAIN    =   3.471295427288E+02 / Maximum equivalent gain (e-/ADU)               SATURATE=   1.127696956565E+03 / Saturation Level (ADU)                         COMMENT                                                                         SOFTNAME= 'SWarp   '           / The software that processed those data         SOFTVERS= '2.41.5  '           / Version of the software                        SOFTDATE= '2023-07-10'         / Release date of the software                   SOFTAUTH= '2010-2012 IAP/CNRS/UPMC' / Maintainer of the software                SOFTINST= 'IAP  http://www.iap.fr' / Institute                                  COMMENT                                                                         AUTHOR  = 'unknown '           / Who ran the software                           ORIGIN  = '569fafe5e8dd'       / Where it was done                              DATE    = '2023-08-09T04:57:47' / When it was started (GMT)                     COMBINET= 'WEIGHTED'           / COMBINE_TYPE config parameter for SWarp        COMMENT                                                                         COMMENT  Propagated FITS keywords                                               AIRMASS =   1.064378635341E+00 / air mass at the end of observation             TELESCOP= 'T80     '           / Telescope Model                                INSTRUME= 'T80Cam  '           / Custom. Name of instrument                     FILTER  = 'F430    '           / Filter used for this observation               COMMENT                                                                         COMMENT  Axis-dependent config parameters                                       RESAMPT1= 'LANCZOS3'           / RESAMPLING_TYPE config parameter               CENTERT1= 'MANUAL  '           / CENTER_TYPE config parameter                   PSCALET1= 'MANUAL  '           / PIXELSCALE_TYPE config parameter               RESAMPT2= 'LANCZOS3'           / RESAMPLING_TYPE config parameter               CENTERT2= 'MANUAL  '           / CENTER_TYPE config parameter                   PSCALET2= 'MANUAL  '           / PIXELSCALE_TYPE config parameter               HIERARCH INSTRUMENT = 'T80S    '                                                PIXSCALE=                 0.55                                                   ...
# 90.42540856542 -39.98499061405 A3376_001
# Unnamed: 0            0
# Field         A3376_001
# RA               90.425
# DEC             -39.985
# Name: 0, dtype: object
# SIMPLE  =                    T / This is a FITS file                            BITPIX  =                  -32                                                  NAXIS   =                    2                                                  NAXIS1  =                11000 / Number of pixels along this axis               NAXIS2  =                11000 / Number of pixels along this axis               EQUINOX =        2000.00000000 / Mean equinox                                   MJD-OBS =       59222.34166667 / Modified Julian date at start                  RADESYS = 'ICRS    '           / Astrometric system                             CTYPE1  = 'RA---TAN'           / WCS projection type for this axis              CUNIT1  = 'deg     '           / Axis unit                                      CRVAL1  =   9.042540856542E+01 / World coordinate on this axis                  CRPIX1  =   5.500500000000E+03 / Reference pixel on this axis                   CD1_1   =  -1.527777777778E-04 / Linear projection matrix                       CD1_2   =   0.000000000000E+00 / Linear projection matrix                       CTYPE2  = 'DEC--TAN'           / WCS projection type for this axis              CUNIT2  = 'deg     '           / Axis unit                                      CRVAL2  =  -3.998499061405E+01 / World coordinate on this axis                  CRPIX2  =   5.500500000000E+03 / Reference pixel on this axis                   CD2_1   =   0.000000000000E+00 / Linear projection matrix                       CD2_2   =   1.527777777778E-04 / Linear projection matrix                       EXPTIME =   1.830000000000E+02 / Maximum equivalent exposure time (s)           GAIN    =   3.714894102136E+02 / Maximum equivalent gain (e-/ADU)               SATURATE=   1.053808174009E+03 / Saturation Level (ADU)                         COMMENT                                                                         SOFTNAME= 'SWarp   '           / The software that processed those data         SOFTVERS= '2.41.5  '           / Version of the software                        SOFTDATE= '2023-07-10'         / Release date of the software                   SOFTAUTH= '2010-2012 IAP/CNRS/UPMC' / Maintainer of the software                SOFTINST= 'IAP  http://www.iap.fr' / Institute                                  COMMENT                                                                         AUTHOR  = 'unknown '           / Who ran the software                           ORIGIN  = '569fafe5e8dd'       / Where it was done                              DATE    = '2023-08-09T07:30:01' / When it was started (GMT)                     COMBINET= 'WEIGHTED'           / COMBINE_TYPE config parameter for SWarp        COMMENT                                                                         COMMENT  Propagated FITS keywords                                               AIRMASS =   1.057145158732E+00 / air mass at the end of observation             TELESCOP= 'T80     '           / Telescope Model                                INSTRUME= 'T80Cam  '           / Custom. Name of instrument                     FILTER  = 'F515    '           / Filter used for this observation               COMMENT                                                                         COMMENT  Axis-dependent config parameters                                       RESAMPT1= 'LANCZOS3'           / RESAMPLING_TYPE config parameter               CENTERT1= 'MANUAL  '           / CENTER_TYPE config parameter                   PSCALET1= 'MANUAL  '           / PIXELSCALE_TYPE config parameter               RESAMPT2= 'LANCZOS3'           / RESAMPLING_TYPE config parameter               CENTERT2= 'MANUAL  '           / CENTER_TYPE config parameter                   PSCALET2= 'MANUAL  '           / PIXELSCALE_TYPE config parameter               HIERARCH INSTRUMENT = 'T80S    '                                                PIXSCALE=                 0.55                                                   ...
# 90.42540856542 -39.98499061405 A3376_001
# Unnamed: 0            0
# Field         A3376_001
# RA               90.425
# DEC             -39.985
# Name: 0, dtype: object
# SIMPLE  =                    T / This is a FITS file                            BITPIX  =                  -32                                                  NAXIS   =                    2                                                  NAXIS1  =                11000 / Number of pixels along this axis               NAXIS2  =                11000 / Number of pixels along this axis               EQUINOX =        2000.00000000 / Mean equinox                                   MJD-OBS =       59222.35625000 / Modified Julian date at start                  RADESYS = 'ICRS    '           / Astrometric system                             CTYPE1  = 'RA---TAN'           / WCS projection type for this axis              CUNIT1  = 'deg     '           / Axis unit                                      CRVAL1  =   9.042540856542E+01 / World coordinate on this axis                  CRPIX1  =   5.500500000000E+03 / Reference pixel on this axis                   CD1_1   =  -1.527777777778E-04 / Linear projection matrix                       CD1_2   =   0.000000000000E+00 / Linear projection matrix                       CTYPE2  = 'DEC--TAN'           / WCS projection type for this axis              CUNIT2  = 'deg     '           / Axis unit                                      CRVAL2  =  -3.998499061405E+01 / World coordinate on this axis                  CRPIX2  =   5.500500000000E+03 / Reference pixel on this axis                   CD2_1   =   0.000000000000E+00 / Linear projection matrix                       CD2_2   =   1.527777777778E-04 / Linear projection matrix                       EXPTIME =   8.700000000000E+02 / Maximum equivalent exposure time (s)           GAIN    =   1.766062725988E+03 / Maximum equivalent gain (e-/ADU)               SATURATE=   2.217051566034E+02 / Saturation Level (ADU)                         COMMENT                                                                         SOFTNAME= 'SWarp   '           / The software that processed those data         SOFTVERS= '2.41.5  '           / Version of the software                        SOFTDATE= '2023-07-10'         / Release date of the software                   SOFTAUTH= '2010-2012 IAP/CNRS/UPMC' / Maintainer of the software                SOFTINST= 'IAP  http://www.iap.fr' / Institute                                  COMMENT                                                                         AUTHOR  = 'unknown '           / Who ran the software                           ORIGIN  = '569fafe5e8dd'       / Where it was done                              DATE    = '2023-08-09T10:20:47' / When it was started (GMT)                     COMBINET= 'WEIGHTED'           / COMBINE_TYPE config parameter for SWarp        COMMENT                                                                         COMMENT  Propagated FITS keywords                                               AIRMASS =   1.035779382648E+00 / air mass at the end of observation             TELESCOP= 'T80     '           / Telescope Model                                INSTRUME= 'T80Cam  '           / Custom. Name of instrument                     FILTER  = 'F660    '           / Filter used for this observation               COMMENT                                                                         COMMENT  Axis-dependent config parameters                                       RESAMPT1= 'LANCZOS3'           / RESAMPLING_TYPE config parameter               CENTERT1= 'MANUAL  '           / CENTER_TYPE config parameter                   PSCALET1= 'MANUAL  '           / PIXELSCALE_TYPE config parameter               RESAMPT2= 'LANCZOS3'           / RESAMPLING_TYPE config parameter               CENTERT2= 'MANUAL  '           / CENTER_TYPE config parameter                   PSCALET2= 'MANUAL  '           / PIXELSCALE_TYPE config parameter               HIERARCH INSTRUMENT = 'T80S    '                                                PIXSCALE=                 0.55                                                   ...
# 90.42540856542 -39.98499061405 A3376_001
# Unnamed: 0            0
# Field         A3376_001
# RA               90.425
# DEC             -39.985
# Name: 0, dtype: object
# SIMPLE  =                    T / This is a FITS file                            BITPIX  =                  -32                                                  NAXIS   =                    2                                                  NAXIS1  =                11000 / Number of pixels along this axis               NAXIS2  =                11000 / Number of pixels along this axis               EQUINOX =        2000.00000000 / Mean equinox                                   MJD-OBS =       59222.36736111 / Modified Julian date at start                  RADESYS = 'ICRS    '           / Astrometric system                             CTYPE1  = 'RA---TAN'           / WCS projection type for this axis              CUNIT1  = 'deg     '           / Axis unit                                      CRVAL1  =   9.042540856542E+01 / World coordinate on this axis                  CRPIX1  =   5.500500000000E+03 / Reference pixel on this axis                   CD1_1   =  -1.527777777778E-04 / Linear projection matrix                       CD1_2   =   0.000000000000E+00 / Linear projection matrix                       CTYPE2  = 'DEC--TAN'           / WCS projection type for this axis              CUNIT2  = 'deg     '           / Axis unit                                      CRVAL2  =  -3.998499061405E+01 / World coordinate on this axis                  CRPIX2  =   5.500500000000E+03 / Reference pixel on this axis                   CD2_1   =   0.000000000000E+00 / Linear projection matrix                       CD2_2   =   1.527777777778E-04 / Linear projection matrix                       EXPTIME =   1.600000000000E+02 / Maximum equivalent exposure time (s)           GAIN    =   3.247626892688E+02 / Maximum equivalent gain (e-/ADU)               SATURATE=   8.036279733309E+02 / Saturation Level (ADU)                         COMMENT                                                                         SOFTNAME= 'SWarp   '           / The software that processed those data         SOFTVERS= '2.41.5  '           / Version of the software                        SOFTDATE= '2023-07-10'         / Release date of the software                   SOFTAUTH= '2010-2012 IAP/CNRS/UPMC' / Maintainer of the software                SOFTINST= 'IAP  http://www.iap.fr' / Institute                                  COMMENT                                                                         AUTHOR  = 'unknown '           / Who ran the software                           ORIGIN  = '569fafe5e8dd'       / Where it was done                              DATE    = '2023-08-09T13:20:37' / When it was started (GMT)                     COMBINET= 'WEIGHTED'           / COMBINE_TYPE config parameter for SWarp        COMMENT                                                                         COMMENT  Propagated FITS keywords                                               AIRMASS =   1.028399552865E+00 / air mass at the end of observation             TELESCOP= 'T80     '           / Telescope Model                                INSTRUME= 'T80Cam  '           / Custom. Name of instrument                     FILTER  = 'F861    '           / Filter used for this observation               COMMENT                                                                         COMMENT  Axis-dependent config parameters                                       RESAMPT1= 'LANCZOS3'           / RESAMPLING_TYPE config parameter               CENTERT1= 'MANUAL  '           / CENTER_TYPE config parameter                   PSCALET1= 'MANUAL  '           / PIXELSCALE_TYPE config parameter               RESAMPT2= 'LANCZOS3'           / RESAMPLING_TYPE config parameter               CENTERT2= 'MANUAL  '           / CENTER_TYPE config parameter                   PSCALET2= 'MANUAL  '           / PIXELSCALE_TYPE config parameter               HIERARCH INSTRUMENT = 'T80S    '                                                PIXSCALE=                 0.55                                                   ...
# 90.42540856542 -39.98499061405 A3376_001
# Unnamed: 0            0
# Field         A3376_001
# RA               90.425
# DEC             -39.985
# Name: 0, dtype: object

# %%
queryres.to_csv("CN_db_antes.csv")

# %%
open("log.txt", "w")

for key, value in queryres.iterrows():
    field = value["field"]
    
    filepath = join(raw_files, value['file_path'])

    if '.fz' in filepath:
        header = fits.getheader(filepath, 1)
    else:
        header = fits.getheader(filepath, 0)
    
    ra, dec = float(header['CRVAL1']), float(header['CRVAL2'])
    
    contains_value = df['Field'].isin([field]).any()
    if not contains_value:
        continue
    row = find_closest_row(ra, dec)

    #write_log(f"Checking field {field}")
    if row is None or field is None:
        write_log(f"Match error in ref {field}")
        print(row)
        print(field, ra, dec)
        continue
    if field != row['Field']:
        write_log(f"{value['file_name']} {field} -> {row['Field']}")
        write_changes(f"{value['file_name']} {value['id']} -> {row['Field']}")

        print(f"Doing {field}")
        # This will update the 'users' table, setting the 'name' column to 'NewName' where 'id' is 1
        updated_rows = update_data(conn, "files_individualfile", ["field"], [row['Field']], "id = %s", [value['id']])
        print(f"{updated_rows} row(s) updated.")

        updated_rows = update_data(conn, "files_finaltiles", ["status"], [0], "field = %s", [field])
        print(f"{updated_rows} row(s) updated.")

        deleted_rows = delete_data(conn, "files_astrocatalogs", "field = %s", [field])
        print(f"{deleted_rows} row(s) deleted.")
# Out:
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-004', 169074]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-004', 169099]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-004', 169196]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-004', 169113]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-004', 169185]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-004', 169183]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-004', 169122]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-004', 169192]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-004', 169132]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-004', 169165]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-004', 169078]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-004', 169213]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-004', 169245]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-004', 169145]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-004', 169090]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-004', 169256]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-004', 169215]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-004', 169241]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-004', 169264]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-001', 171049]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-001', 171117]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-001', 171248]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-001', 171133]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-001', 171184]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-001', 171215]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-001', 171077]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-001', 171045]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-001', 171080]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-001', 171238]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-001', 171104]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-001', 171130]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-001', 171220]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-001', 171266]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-001', 171232]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-006', 173127]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-002', 173099]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-002', 173109]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-002', 173090]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-002', 173082]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-006', 173095]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-002', 173069]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-002', 173101]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-006', 173123]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-002', 173078]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-006', 173073]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-002', 173100]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-006', 173120]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-006', 173117]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-006', 173089]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-007', 173139]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-006', 173079]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-002', 173066]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-002', 173083]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-007', 173147]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-006', 173129]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-007', 173167]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-007', 173157]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-006', 173103]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-006', 173094]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-007', 173141]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-002', 173122]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-007', 173158]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-006', 173132]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-006', 173065]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-007', 173160]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-002', 173092]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-006', 173085]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-007', 173171]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-007', 173149]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-006', 173074]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-007', 173133]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-007', 173145]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-006', 173086]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-006', 173105]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-007', 173128]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-002', 173077]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-006', 173071]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-002', 173134]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-002', 173097]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-006', 173125]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-007', 173161]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-007', 173163]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-007', 173152]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-006', 173115]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-006', 173070]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-002', 173138]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-007', 173162]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-007', 173146]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-007', 173153]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-007', 173159]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-007', 173168]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-003', 176991]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-003', 176984]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-003', 176992]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-003', 176970]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-003', 176973]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-003', 176993]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-003', 176999]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-003', 176955]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-003', 176945]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-003', 176997]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-003', 176977]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-003', 176966]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-003', 177003]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-003', 176968]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-003', 177010]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-003', 176974]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-003', 177000]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-003', 176981]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-003', 176943]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-003', 176985]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-005', 177443]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-003', 177012]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-005', 177451]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-005', 177446]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-005', 177486]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-005', 177455]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-005', 177475]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-005', 177428]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-005', 177471]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-005', 177444]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-005', 177487]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-005', 177477]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-005', 177467]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-005', 177494]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-005', 177485]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-005', 177493]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-005', 177491]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-004', 178571]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-004', 178586]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-004', 178621]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-006', 178598]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-004', 178606]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-006', 178601]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-004', 178624]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-006', 178618]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-004', 178578]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-004', 178596]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-006', 178568]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-004', 178617]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-007', 178850]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-004', 178590]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-005', 178804]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-006', 178640]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-007', 178828]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-006', 178582]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-006', 178631]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-006', 178573]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-007', 178842]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-006', 178619]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-004', 178592]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-007', 178853]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-007', 178832]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-005', 178859]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-004', 178609]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-003', 178926]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-005', 178825]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-006', 178576]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-005', 178800]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-004', 178602]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-007', 178811]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-006', 178623]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-006', 178613]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-005', 178849]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-005', 178829]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-004', 178594]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-005', 178819]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-006', 178574]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-003', 178934]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-006', 178626]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-005', 178839]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-005', 178864]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-005', 178851]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-004', 178616]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-006', 178589]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-007', 178863]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-003', 178935]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-006', 178597]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-006', 178607]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-005', 178796]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-004', 178633]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-003', 178933]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-005', 178831]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-004', 178632]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-004', 178612]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-003', 178944]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-005', 178812]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-004', 178625]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-003', 178932]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-007', 178813]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-005', 178858]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-004', 178615]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-007', 178794]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-006', 178622]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-007', 178817]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-005', 178807]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-007', 178862]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-004', 178629]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-007', 178840]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-007', 178856]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-003', 178929]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-007', 178845]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-003', 178938]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-005', 178855]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-003', 178928]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-005', 178810]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-005', 178857]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-007', 178837]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-005', 178847]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-005', 178808]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-002', 181897]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-002', 181946]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-002', 181905]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-002', 181947]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-002', 181895]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-002', 181884]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-002', 181943]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-002', 181933]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-002', 181923]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-002', 181911]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-002', 181927]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-002', 181938]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-002', 181907]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-001', 182160]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-001', 182151]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-001', 182185]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-002', 181916]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-001', 182139]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-001', 182155]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-002', 181945]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-001', 182137]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-002', 181929]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-002', 181950]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-002', 181939]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-001', 182191]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-001', 182162]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-001', 182181]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-003', 182368]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-001', 182174]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-003', 182416]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-001', 182140]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-003', 182381]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-001', 182199]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-003', 182429]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-001', 182187]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-001', 182153]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-003', 182412]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-003', 182394]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-001', 182206]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-001', 182168]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-003', 182379]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-001', 182178]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-003', 182440]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-003', 182423]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-001', 182146]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-001', 182175]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-003', 182409]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-003', 182372]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-003', 182385]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-003', 182383]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-003', 182428]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-003', 182407]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-003', 182421]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-003', 182378]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-003', 182434]
# None row(s) updated.
# WARNING: File may have been truncated: actual file length (65748992) is smaller than the expected size (82923840) [astropy.io.fits.file]
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A147-007', 232852]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A147-007', 232857]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A147-007', 232870]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A147-007', 232901]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A147-007', 232889]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A147-007', 232838]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A147-007', 232854]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A147-007', 232837]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A147-007', 232843]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A147-007', 232879]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A147-007', 232842]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A147-007', 232875]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A147-007', 232866]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A147-007', 232883]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A147-007', 232882]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A147-007', 232902]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A147-007', 232892]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A147-007', 232886]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-001', 256248]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-001', 256252]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-006', 256497]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-007', 256506]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-007', 256219]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-005', 256518]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-004', 256491]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-003', 256226]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-002', 256569]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-001', 256496]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-006', 256223]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-006', 256218]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-002', 256247]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-002', 256493]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-005', 256520]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-005', 256238]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-005', 256233]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-004', 256211]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-004', 256511]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-005', 256228]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-003', 256253]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-002', 256507]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-003', 256242]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-006', 256239]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-002', 256522]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-004', 169239]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-001', 171225]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-001', 171205]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-007', 173164]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-002', 173114]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-007', 178854]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-007', 178846]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-003', 182425]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-003', 256571]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-001', 182202]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-003', 182430]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-001', 257403]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-006', 256501]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-001', 256494]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-006', 256505]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-006', 256512]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-005', 256509]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-004', 169238]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-007', 173154]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-007', 173155]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-005', 177462]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-005', 256498]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-007', 256502]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-001', 256495]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-007', 256499]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-004', 256492]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-004', 256490]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-002', 256500]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-007', 256513]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-003', 256503]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-004', 256508]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-005', 256510]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-007', 256515]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-005', 256519]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-004', 256514]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-007', 256517]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-003', 256525]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-002', 256521]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-001', 256524]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-006', 256516]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-001', 256568]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-001', 256570]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-005', 178836]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-003', 257222]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-006', 178603]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-003', 256504]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-004', 178604]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-002', 181920]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-004', 257210]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-001', 257212]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-006', 257213]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-004', 257208]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-004', 169151]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-001', 171218]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-006', 173142]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-006', 173130]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-006', 257218]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-007', 173170]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-002', 257223]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-003', 257224]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-002', 173124]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-002', 257220]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-002', 173121]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-002', 173126]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-004', 257219]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-003', 182398]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-003', 177011]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-005', 177501]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-005', 257231]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-002', 257241]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-002', 257233]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-007', 257240]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-005', 177431]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-004', 257235]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-004', 178635]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-007', 178861]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-007', 178860]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-004', 178634]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-006', 178630]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-002', 181883]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-005', 257230]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-006', 257236]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-001', 182201]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-003', 182371]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-001', 257211]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-003', 257246]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-007', 257234]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-003', 257243]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-003', 257225]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-006', 257214]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-001', 257247]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-004', 257229]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-006', 257238]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-007', 257217]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-001', 257245]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-005', 257227]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-007', 257215]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-001', 257242]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-001', 171182]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-002', 173091]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-006', 173104]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-006', 173102]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-003', 176983]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-007', 178822]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-005', 178833]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-007', 178830]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-002', 181918]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-004', 255546]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-004', 255561]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-006', 255585]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-004', 255645]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-002', 255580]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-005', 255590]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-003', 255642]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-001', 255599]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-002', 255650]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-006', 256217]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-004', 169247]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-004', 169140]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-004', 255562]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-001', 255577]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-007', 255575]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-007', 173166]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-007', 255581]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-001', 171229]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-002', 173107]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-006', 173111]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-006', 173113]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-007', 255586]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-001', 171039]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-002', 255582]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-006', 255584]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-007', 255596]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-003', 255601]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-005', 177480]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-007', 178835]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-005', 178843]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-001', 182189]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-001', 255600]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-003', 182410]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-006', 255594]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-007', 255592]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-002', 255598]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-005', 255589]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-005', 177479]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-006', 178611]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-006', 255646]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-006', 178614]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-005', 178844]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-002', 181931]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-002', 181934]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-006', 255647]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-005', 255649]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-002', 255651]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-005', 255644]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-003', 182419]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-005', 255595]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-001', 255579]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-003', 255588]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-003', 255653]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-004', 257209]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-003', 257248]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-002', 257244]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-005', 257226]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-007', 257237]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-007', 257221]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-005', 257228]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-002', 257216]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-006', 257232]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-004', 259835]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-007', 178848]
# ...
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-005', 279983]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-005', 280613]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3490-006', 280133]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-001', 280013]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3490-002', 281257]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A147-007', 232856]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A147-007', 280222]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3490-006', 280131]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3490-004', 280137]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3490-004', 280139]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A147-007', 280221]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-007', 280247]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-005', 280256]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-007', 280258]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-007', 280248]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-005', 280259]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-001', 280292]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-007', 280246]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-007', 280255]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3490-006', 280417]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-001', 280988]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-007', 281340]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-001', 280293]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3490-006', 280418]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3490-004', 280423]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3490-004', 280422]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3490-006', 280824]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A147-007', 232884]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A147-007', 280505]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A147-007', 280504]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A147-007', 280503]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-007', 280540]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-005', 280538]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-001', 280568]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-001', 280570]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-007', 280537]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-001', 280644]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3490-006', 280416]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-007', 280952]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-001', 281377]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-001', 281533]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3490-004', 281395]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-001', 281456]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-005', 280961]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-007', 280529]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-005', 280539]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-001', 280569]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-007', 280617]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-005', 280614]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-001', 280647]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3490-006', 280825]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3490-004', 280831]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3490-004', 280832]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-007', 280951]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A147-007', 280922]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A147-007', 232896]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A147-007', 280923]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A147-007', 280926]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-007', 280607]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-007', 280616]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-001', 280645]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3490-006', 280826]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3490-004', 280830]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-007', 280953]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-007', 280957]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-007', 280958]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-007', 280959]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-005', 280962]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-001', 280990]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-001', 280987]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3490-002', 281063]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3490-002', 281065]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3490-002', 281258]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-007', 281143]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-007', 281144]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-007', 281149]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-005', 281154]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-001', 281182]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-001', 281183]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-005', 281153]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-001', 281184]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-005', 281341]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-007', 281338]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-007', 281343]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-007', 281326]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-001', 281378]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-007', 281422]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3490-004', 281473]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-007', 281499]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-005', 281347]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-005', 281345]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-001', 281375]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-005', 281427]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-005', 281426]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-001', 281452]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3490-004', 281393]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-007', 281498]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-005', 281428]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-001', 281455]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3490-004', 281474]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-005', 281504]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-005', 281506]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-001', 281532]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-007', 281500]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-001', 281531]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['Abell3490-005', 281505]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-004', 169167]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-006', 178628]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-001', 182136]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-003', 182436]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-004', 169231]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-004', 178567]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-004', 169258]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-007', 173165]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-004', 178620]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-001', 182195]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-002', 258968]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-004', 258982]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-006', 258989]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-001', 258998]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-002', 173084]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-003', 176976]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-002', 181914]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-002', 256216]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-001', 256213]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-002', 256221]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-006', 173072]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-004', 178577]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-004', 256230]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-006', 256236]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-007', 256243]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-006', 256237]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-002', 173118]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-003', 176957]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-005', 257454]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-005', 276310]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-001', 276325]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-003', 177009]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-001', 171135]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-003', 176980]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-002', 257401]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-007', 259186]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-003', 256523]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-001', 182198]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-004', 169201]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-006', 173110]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-005', 178841]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-004', 255591]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-003', 276585]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-005', 259831]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-004', 256212]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-003', 259825]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-001', 259848]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-002', 256245]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-004', 276305]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A3667-003', 260031]
# None row(s) updated.
# UPDATE files_individualfile SET field = %s WHERE id = %s ['A0085-001', 255576]
# None row(s) updated.

# %%
# This will update the 'users' table, setting the 'name' column to 'NewName' where 'id' is 1
updated_rows = update_data(conn, "files_individualfile", ["field"], ["TESTE"], "id = %s", [1])

print(f"{updated_rows} row(s) updated.")
# Out:
# UPDATE files_individualfile SET field = %s WHERE id = %s ['TESTE', 1]
# None row(s) updated.
