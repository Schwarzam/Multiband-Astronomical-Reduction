# %%
import mar
import os

from mar.wrappers.wrappersoperation import *

from astropy.table import Table
from astropy.io import fits

# %%
tuple(list((6, 30.0, 5.0, 7.0, 10.0, 35.0)))
# Out:
# (6, 30.0, 5.0, 7.0, 10.0, 35.0)

# %%
def createVignetCatalog(image, output):
    conf = {
        "CATALOG_NAME": output,

        "WEIGHT_TYPE": "NONE",

        "BACK_FILTERSIZE": 5,
        "BACK_SIZE": 512,
        "DETECT_THRESH": 10.0,
        "ANALYSIS_THRESH": 10.0,
        "DETECT_MINAREA": 10,

        "CATALOG_TYPE": 'FITS_LDAC',
        "PHOT_AUTOPARAMS": '2.5,3.5',
        "CHECKIMAGE_TYPE": "NONE",
        "PHOT_FLUXFRAC": "0.5",

        "FILTER_NAME": os.path.join(mar.__path__[0], 'config/sextractor/gauss_3.0_5x5.conv'), 
        "FILTER": "Y",
        "PHOT_APERTURES": ("%.2f, %.2f, %.2f, %.2f, %.2f, %.2f" % (6, 30.0, 5.0, 7.0, 10.0, 35.0))

    }

    numapers = 6
    vignetsize = [51, 51]

    params = [
                "NUMBER",
                "ALPHA_J2000",
                "DELTA_J2000",
                "VIGNET({0},{1})".format(vignetsize[0], vignetsize[1]),
                "X_IMAGE", "Y_IMAGE",
                "FLUX_AUTO", "FLUXERR_AUTO",
                "MAG_AUTO", "MAGERR_AUTO",
                "FLUX_APER({0})".format(numapers),
                "FLUXERR_APER({0})".format(numapers),
                "MAG_APER({0})".format(numapers),
                "MAGERR_APER({0})".format(numapers),
                "FWHM_IMAGE", "ISOAREA_IMAGE",
                "FLUX_RADIUS", "FLUX_MAX",
                "ELLIPTICITY", "ELONGATION",
                "SNR_WIN",
                "FLAGS",
                "FLAGS_WEIGHT",
                "CLASS_STAR",
                "XWIN_IMAGE", "YWIN_IMAGE"
    ]

    from mar.wrappers.sextractor import SExtr

    inst = SExtr(image=image, folder="./outputs", addconf=conf)
    inst.params = params
    inst.run()

# %%
createVignetCatalog("/home/gustavo/Downloads/_media_files_HYDRA-0023_R_swp", "outputs/final.fits")
# Out:
# >
# ----- SExtractor 2.25.2 started on 2023-02-07 at 14:50:27 with 1 thread
#
# > Setting catalog parameters
# > Reading detection filter
# > Initializing Neural Network
# > Reading Neural Network Weights
# > Initializing catalog
# > Looking for _media_files_HYDRA-0023_R_swp
# ----- Measuring from: _media_files_HYDRA-0023_R_swp
#       "HYDRA_0023" / no ext. header / 11000x11000 / 32 bits (floats)
# Detection+Measurement image: > Setting up background maps
# > Setting up background map at line:  512
# > Setting up background map at line: 1024
# > Setting up background map at line: 1536
# > Setting up background map at line: 2048
# > Setting up background map at line: 2560
# > Setting up background map at line: 3072
# > Setting up background map at line: 3584
# > Setting up background map at line: 4096
# > Setting up background map at line: 4608
# > Setting up background map at line: 5120
# > Setting up background map at line: 5632
# > Setting up background map at line: 6144
# > Setting up background map at line: 6656
# > Setting up background map at line: 7168
# > Setting up background map at line: 7680
# > Setting up background map at line: 8192
# > Setting up background map at line: 8704
# > Setting up background map at line: 9216
# > Setting up background map at line: 9728
# > Setting up background map at line:10240
# > Setting up background map at line:10752
# > Filtering background map(s)
# > Computing background d-map
# > Computing background-noise d-map
# (M+D) Background: 8.97198e-05 RMS: 0.185032   / Threshold: 1.85032
# > Scanning image
# > Line:   25  Objects:        0 detected /        0 sextracted
# > Line:   50  Objects:        0 detected /        0 sextracted
# > Line:   75  Objects:        0 detected /        0 sextracted
# > Line:  100  Objects:        0 detected /        0 sextracted
# > Line:  125  Objects:        0 detected /        0 sextracted
# > Line:  150  Objects:        0 detected /        0 sextracted
# > Line:  175  Objects:        0 detected /        0 sextracted
# > Line:  200  Objects:        0 detected /        0 sextracted
# > Line:  225  Objects:        0 detected /        0 sextracted
# > Line:  250  Objects:        0 detected /        0 sextracted
# > Line:  275  Objects:        0 detected /        0 sextracted
# > Line:  300  Objects:        0 detected /        0 sextracted
# > Line:  325  Objects:        0 detected /        0 sextracted
# > Line:  350  Objects:        0 detected /        0 sextracted
# > Line:  375  Objects:        0 detected /        0 sextracted
# > Line:  400  Objects:        0 detected /        0 sextracted
# > Line:  425  Objects:        0 detected /        0 sextracted
# > Line:  450  Objects:        0 detected /        0 sextracted
# > Line:  475  Objects:        0 detected /        0 sextracted
# > Line:  500  Objects:        0 detected /        0 sextracted
# > Line:  525  Objects:        0 detected /        0 sextracted
# > Line:  550  Objects:        0 detected /        0 sextracted
# > Line:  575  Objects:        0 detected /        0 sextracted
# > Line:  600  Objects:        0 detected /        0 sextracted
# > Line:  625  Objects:        0 detected /        0 sextracted
# > Line:  650  Objects:        0 detected /        0 sextracted
# > Line:  675  Objects:        0 detected /        0 sextracted
# > Line:  700  Objects:        0 detected /        0 sextracted
# > Line:  725  Objects:        0 detected /        0 sextracted
# > Line:  750  Objects:        0 detected /        0 sextracted
# > Line:  775  Objects:        0 detected /        0 sextracted
# > Line:  800  Objects:        0 detected /        0 sextracted
# > Line:  825  Objects:        0 detected /        0 sextracted
# > Line:  850  Objects:        0 detected /        0 sextracted
# > Line:  875  Objects:        5 detected /        0 sextracted
# > Line:  900  Objects:       21 detected /        0 sextracted
# > Line:  925  Objects:       39 detected /        0 sextracted
# > Line:  950  Objects:       65 detected /        0 sextracted
# > Line:  975  Objects:       84 detected /        0 sextracted
# > Line: 1000  Objects:      113 detected /        0 sextracted
# > Line: 1025  Objects:      130 detected /        0 sextracted
# > Line: 1050  Objects:      160 detected /        0 sextracted
# > Line: 1075  Objects:      181 detected /        0 sextracted
# > Line: 1100  Objects:      209 detected /        0 sextracted
# > Line: 1125  Objects:      233 detected /        0 sextracted
# > Line: 1150  Objects:      266 detected /        0 sextracted
# > Line: 1175  Objects:      295 detected /        0 sextracted
# > Line: 1200  Objects:      316 detected /        0 sextracted
# > Line: 1225  Objects:      346 detected /        0 sextracted
# > Line: 1250  Objects:      370 detected /        0 sextracted
# > Line: 1275  Objects:      404 detected /        0 sextracted
# > Line: 1300  Objects:      424 detected /        0 sextracted
# > Line: 1325  Objects:      439 detected /        0 sextracted
# > Line: 1350  Objects:      474 detected /        0 sextracted
# > Line: 1375  Objects:      510 detected /        0 sextracted
# > Line: 1400  Objects:      529 detected /        0 sextracted
# > Line: 1425  Objects:      556 detected /        0 sextracted
# > Line: 1450  Objects:      582 detected /        0 sextracted
# > Line: 1475  Objects:      601 detected /        0 sextracted
# > Line: 1500  Objects:      631 detected /        0 sextracted
# > Line: 9725  Objects:     8490 detected /        0 sextracted
# > Line: 9750  Objects:     8509 detected /        0 sextracted
# > Line: 9775  Objects:     8533 detected /        0 sextracted
# > Line: 9800  Objects:     8554 detected /        0 sextracted
# > Line: 9825  Objects:     8583 detected /        0 sextracted
# > Line: 9850  Objects:     8602 detected /        0 sextracted
# > Line: 9875  Objects:     8623 detected /        0 sextracted
# > Line: 9900  Objects:     8644 detected /        0 sextracted
# > Line: 9925  Objects:     8666 detected /        0 sextracted
# > Line: 9950  Objects:     8697 detected /        0 sextracted
# > Line: 9975  Objects:     8715 detected /        0 sextracted
# > Line:10000  Objects:     8740 detected /        0 sextracted
# > Line:10025  Objects:     8762 detected /        0 sextracted
# > Line:10050  Objects:     8788 detected /        0 sextracted
# > Line:10075  Objects:     8813 detected /        0 sextracted
# > Line:10100  Objects:     8838 detected /        0 sextracted
# > Line:10125  Objects:     8850 detected /        0 sextracted
# > Line:10150  Objects:     8867 detected /        0 sextracted
# > Line:10175  Objects:     8878 detected /        0 sextracted
# > Line:10200  Objects:     8882 detected /        0 sextracted
# > Line:10225  Objects:     8882 detected /        0 sextracted
# > Line:10250  Objects:     8882 detected /        0 sextracted
# > Line:10275  Objects:     8882 detected /        0 sextracted
# > Line:10300  Objects:     8882 detected /        0 sextracted
# > Line:10325  Objects:     8882 detected /        0 sextracted
# > Line:10350  Objects:     8882 detected /        0 sextracted
# > Line:10375  Objects:     8882 detected /        0 sextracted
# > Line:10400  Objects:     8882 detected /        0 sextracted
# > Line:10425  Objects:     8882 detected /        0 sextracted
# > Line:10450  Objects:     8882 detected /        0 sextracted
# > Line:10475  Objects:     8882 detected /        0 sextracted
# > Line:10500  Objects:     8882 detected /        0 sextracted
# > Line:10525  Objects:     8882 detected /        0 sextracted
# > Line:10550  Objects:     8882 detected /        0 sextracted
# > Line:10575  Objects:     8882 detected /        0 sextracted
# > Line:10600  Objects:     8882 detected /        0 sextracted
# > Line:10625  Objects:     8882 detected /        0 sextracted
# > Line:10650  Objects:     8882 detected /        0 sextracted
# > Line:10675  Objects:     8882 detected /        0 sextracted
# > Line:10700  Objects:     8882 detected /        0 sextracted
# > Line:10725  Objects:     8882 detected /        0 sextracted
# > Line:10750  Objects:     8882 detected /        0 sextracted
# > Line:10775  Objects:     8882 detected /        0 sextracted
# > Line:10800  Objects:     8882 detected /        0 sextracted
# > Line:10825  Objects:     8882 detected /        0 sextracted
# > Line:10850  Objects:     8882 detected /        0 sextracted
# > Line:10875  Objects:     8882 detected /        0 sextracted
# > Line:10900  Objects:     8882 detected /        0 sextracted
# > Line:10925  Objects:     8882 detected /        0 sextracted
# > Line:10950  Objects:     8882 detected /        0 sextracted
# > Line:10975  Objects:     8882 detected /        0 sextracted
# > Line:11000  Objects:     8882 detected /        0 sextracted
# > Line:11000  Objects:     8882 detected /        0 sextracted
# > Line:11000  Objects:     8882 detected /      400 sextracted
# > Line:11000  Objects:     8882 detected /      800 sextracted
# > Line:11000  Objects:     8882 detected /     1200 sextracted
# > Line:11000  Objects:     8882 detected /     1600 sextracted
# > Line:11000  Objects:     8882 detected /     2000 sextracted
# > Line:11000  Objects:     8882 detected /     2400 sextracted
# > Line:11000  Objects:     8882 detected /     2800 sextracted
# > Line:11000  Objects:     8882 detected /     3200 sextracted
# > Line:11000  Objects:     8882 detected /     3600 sextracted
# > Line:11000  Objects:     8882 detected /     4000 sextracted
# > Line:11000  Objects:     8882 detected /     4400 sextracted
# > Line:11000  Objects:     8882 detected /     4800 sextracted
# > Line:11000  Objects:     8882 detected /     5200 sextracted
# > Line:11000  Objects:     8882 detected /     5600 sextracted
# > Line:11000  Objects:     8882 detected /     6000 sextracted
# > Line:11000  Objects:     8882 detected /     6400 sextracted
# > Line:11000  Objects:     8882 detected /     6800 sextracted
# > Line:11000  Objects:     8882 detected /     7200 sextracted
# > Line:11000  Objects:     8882 detected /     7600 sextracted
# > Line:11000  Objects:     8882 detected /     8000 sextracted
# > Line:11000  Objects:     8882 detected /     8400 sextracted
#       Objects: detected 8882     / sextracted 8778
#
# > Closing files
# >
# > All done (in 4.5 s: 2441.3 lines/s , 1948.1 detections/s)

# %%
def filterCatalogToPSFex(tablepath):
	t = Table.read(tablepath, hdu=2)
	f = fits.open(tablepath, mode='update')

	selection = (
				(t["FLAGS"] == 0) &
				(t["MAGERR_AUTO"] < 0.01) &
				(t["ELLIPTICITY"] < 0.2) &
				(t["ISOAREA_IMAGE"] > 40) &
				(t["SNR_WIN"] < 1000)
			)

	f[2].data = t[selection].as_array()
	f.flush()

# %%
filterCatalogToPSFex("outputs/final.fits")

# %%
len(Table.read("outputs/final.fits", hdu=2))
# Out:
# 2023

# %%
class PSFex(readWriteCats):
    def __init__(self, catalog=None, command = "psfex", folder = "./outputs/"):
        readWriteCats.__init__(self)

        self.command = command
        self.catalog = catalog
        self.folder = folder

        self.config = {
            #PSF model
            'BASIS_TYPE': {'value': 'PIXEL_AUTO', 'comment': 'NONE, PIXEL, GAUSS-LAGUERRE or FILE'},
            'BASIS_NUMBER': {'value': '20', 'comment': 'Basis number or parameter'},
            'BASIS_NAME': {'value': 'basis.fits', 'comment': 'Basis filename (FITS data-cube)'},
            'BASIS_SCALE': {'value': '1.0', 'comment': 'Gauss-Laguerre beta parameter'},
            'NEWBASIS_TYPE': {'value': 'NONE', 'comment': ' or PCA_COMMON'},
            'NEWBASIS_NUMBER': {'value': '8', 'comment': 'Number of new basis vectors'},
            'PSF_SAMPLING': {'value': '0.0', 'comment': 'Sampling step in pixel units (0.0 = auto)'},
            'PSF_PIXELSIZE': {'value': '1.0', 'comment': 'Effective pixel size in pixel step units'},
            'PSF_ACCURACY': {'value': '0.01', 'comment': 'Accuracy to expect from PSF "pixel" values'},
            'PSF_SIZE': {'value': '25,25', 'comment': 'Image size of the PSF model'},
            'PSF_DGEOCORRECT': {'value': 'N', 'comment': 'Use diff. geom. maps (if provided) Y/N?'},
            'PSF_RECENTER': {'value': 'N', 'comment': 'Allow recentering of PSF-candidates Y/N ?'},
            'MEF_TYPE': {'value': 'INDEPENDENT', 'comment': 'INDEPENDENT or COMMON'},

            #Point source measurements
            'CENTER_KEYS': {'value': 'X_IMAGE,Y_IMAGE', 'comment': 'Catalogue parameters for source pre-centering'},
            'PHOTFLUX_KEY': {'value': 'FLUX_APER(1)', 'comment': 'Catalogue parameter for photometric norm.'},
            'PHOTFLUXERR_KEY': {'value': 'FLUXERR_APER(1)', 'comment': 'Catalogue parameter for photometric error'},
            
            #PSF variability
            'PSFVAR_KEYS': {'value': 'X_IMAGE,Y_IMAGE', 'comment': 'Catalogue or FITS (preceded by :) params'},
            'PSFVAR_GROUPS': {'value': '1,1', 'comment': 'Group tag for each context key'},
            'PSFVAR_DEGREES': {'value': '2', 'comment': 'Polynom degree for each group'},
            'PSFVAR_NSNAP': {'value': '9', 'comment': 'Number of PSF snapshots per axis'},
            'HIDDENMEF_TYPE': {'value': 'COMMON', 'comment': 'INDEPENDENT or COMMON'},
            'STABILITY_TYPE': {'value': 'EXPOSURE', 'comment': 'EXPOSURE or SEQUENCE'},
            
            #Sample selection
            'SAMPLE_AUTOSELECT': {'value': 'Y', 'comment': 'Automatically select the FWHM (Y/N) ?'},
            'SAMPLEVAR_TYPE': {'value': 'SEEING', 'comment': 'File-to-file PSF variability: NONE or SEEING'},
            'SAMPLE_FWHMRANGE': {'value': '2.0,10.0', 'comment': 'Allowed FWHM range'},
            'SAMPLE_VARIABILITY': {'value': '0.2', 'comment': 'Allowed FWHM variability (1.0 = 100%)'},
            'SAMPLE_MINSN': {'value': '20', 'comment': 'Minimum S/N for a source to be used'},
            'SAMPLE_MAXELLIP': {'value': '0.3', 'comment': 'Maximum (A-B)/(A+B) for a source to be used'},
            'SAMPLE_FLAGMASK': {'value': '0x00fe', 'comment': 'Rejection mask on SExtractor FLAGS'},
            'SAMPLE_WFLAGMASK': {'value': '0x0000', 'comment': 'Rejection mask on SExtractor FLAGS_WEIGHT'},
            'SAMPLE_IMAFLAGMASK': {'value': '0x0', 'comment': 'Rejection mask on SExtractor IMAFLAGS_ISO'},
            'BADPIXEL_FILTER': {'value': 'N', 'comment': 'Filter bad-pixels in samples (Y/N) ?'},
            'BADPIXEL_NMAX': {'value': '0', 'comment': 'Maximum number of bad pixels allowed'},
            
            #PSF homogeneisation kernel
            'HOMOBASIS_TYPE': {'value': 'NONE', 'comment': 'NONE or GAUSS-LAGUERRE'},
            'HOMOBASIS_NUMBER': {'value': '10', 'comment': 'Kernel basis number or parameter'},
            'HOMOBASIS_SCALE': {'value': '1.0', 'comment': 'GAUSS-LAGUERRE beta parameter'},
            'HOMOPSF_PARAMS': {'value': '2.0, 3.0', 'comment': 'Moffat parameters of the idealised PSF'},
            'HOMOKERNEL_DIR': {'value': '', 'comment': 'Where to write kernels (empty=same as input)'},
            'HOMOKERNEL_SUFFIX': {'value': '.homo.fits', 'comment': 'Filename extension for homogenisation kernels'},
            
            #Output catalogs
            'OUTCAT_TYPE': {'value': 'NONE', 'comment': 'NONE, ASCII_HEAD, ASCII, FITS_LDAC'},
            'OUTCAT_NAME': {'value': 'psfex_out.cat', 'comment': 'Output catalog filename'},
            
            #Check-plots
            'CHECKPLOT_DEV': {'value': 'PNG', 'comment': ' JPEG, AQT, PDF or SVG'},
            'CHECKPLOT_RES': {'value': '0', 'comment': 'Check-plot resolution (0 = default)'},
            'CHECKPLOT_ANTIALIAS': {'value': 'Y', 'comment': 'Anti-aliasing using convert (Y/N) ?'},
            'CHECKPLOT_TYPE': {'value': 'NONE', 'comment': 'SELECTION_FWHM,FWHM,ELLIPTICITY,COUNTS,COUNT_FRACTION,CHI2, RESIDUALS or NONE'},
            'CHECKPLOT_NAME': {'value': 'selfwhm,fwhm,ellipticity,counts,countfrac,chi2,resi', 'comment': ''},
            
            #Check-Images
            'CHECKIMAGE_TYPE': {'value': 'NONE', 'comment': 'CHI,PROTOTYPES,SAMPLES,RESIDUALS,SNAPSHOTS or MOFFAT,-MOFFAT,-SYMMETRICAL'},
            'CHECKIMAGE_NAME': {'value': 'chi.fits,proto.fits,samp.fits,resi.fits,snap.fits', 'comment': ' Check-image filenames'},
            'CHECKIMAGE_CUBE': {'value': 'N', 'comment': 'Save check-images as datacubes (Y/N) ?'},
            'PSF_DIR': {'value': os.path.join(folder, ''), 'comment': 'Where to write PSFs (empty=same as input)'},
            'PSF_SUFFIX': {'value': '.psf', 'comment': 'Filename extension for output PSF filename'},
            'VERBOSE_TYPE': {'value': 'NORMAL', 'comment': 'can be QUIET,NORMAL,LOG or FULL'},
            'WRITE_XML': {'value': 'Y', 'comment': 'Write XML file (Y/N)?'},
            'XML_NAME': {'value': os.path.join(folder, 'psfex.xml'), 'comment': 'Filename for XML output'},
            'XSL_URL': {'value': 'file:///usr/local/share/psfex/psfex.xsl', 'comment': ' Filename for XSL style-sheet'},
            'NTHREADS': {'value': '0', 'comment': ' 0 = automatic'}

        }

    def run(self):
        self.confile = os.path.join(self.folder, 'config.psfex')
        self.write_file(self.confile, mode="scamp")

        MarManager.INFO('Running - PSFex')

        command = self.command + " " + self.catalog + " -c " + self.confile

        os.system(command)

    def getPSFinfo(self):
        v = votable.parse(os.path.join(self.folder, 'psfex.xml'))
        table = v.get_table_by_id('PSF_Fields')

        data = table.array

        keys = ["NStars_Loaded_Total",
                "NStars_Accepted_Total",
                "FWHM_Mean",  # pixel unit
                "FWHM_Min",  # pixel
                "FWHM_Max",  # pixel 
                "Chi2_Mean",
                "MoffatBeta_Mean",
                "Asymmetry_Mean",
                "Ellipticity_Mean"]

        # return {key: data[key].data[0] for key in keys}
        info = {}
        for key in keys:
            info[key] = data[key].data[0]
        
        return info

# %%
psf = PSFex(catalog="t.fits")

# %%
psf.run()
# Out:
# > WARNING: This executable has been compiled using a version of the ATLAS library without support for multithreading. Performance will be degraded.
#
# >
# ----- PSFEx 3.23.0 started on 2023-02-07 at 14:41:18 with 12 threads
#
# >
# ----- 1 input catalogues:
# t.fits              :  "STRIPE82_0002   "    1 extension     324 detections
#
# > Initializing contexts...
# > Computing optimum PSF sampling steps...
# > Reading data from t...
# > Computing final PSF model for t...
#    filename      [ext] accepted/total samp. chi2/dof FWHM ellip. resi. asym.
# > Computing diagnostics for t...
# t                          235/317     0.82   1.35   2.92  0.02  0.02  0.01
# > Saving PSF model and metadata for t...
# > Writing XML file...
# >
# > All done (in 0.0 s)

# %%
psf.getPSFinfo()
# Out:
# {'NStars_Loaded_Total': 317,
#  'NStars_Accepted_Total': 235,
#  'FWHM_Mean': 2.91726,
#  'FWHM_Min': 2.82655,
#  'FWHM_Max': 3.17903,
#  'Chi2_Mean': 1.35199,
#  'MoffatBeta_Mean': 2.51649,
#  'Asymmetry_Mean': 0.0143011,
#  'Ellipticity_Mean': 0.0154316}

# %%
import mar

# %%
mar.wrappers.createVignetCatalog("/home/gustavo/Downloads/_media_files_HYDRA-0111_F378_swp", "./outputs/final.test.fits")
# Out:
# >
# ----- SExtractor 2.25.2 started on 2023-02-07 at 17:06:24 with 1 thread
#
# > Setting catalog parameters
# > Reading detection filter
# > Initializing Neural Network
# > Reading Neural Network Weights
# > Initializing catalog
# > Looking for _media_files_HYDRA-0111_F378_swp
# ----- Measuring from: _media_files_HYDRA-0111_F378_swp
#       "HYDRA_0111" / no ext. header / 11000x11000 / 32 bits (floats)
# Detection+Measurement image: > Setting up background maps
# > Setting up background map at line:  512
# > Setting up background map at line: 1024
# > Setting up background map at line: 1536
# > Setting up background map at line: 2048
# > Setting up background map at line: 2560
# > Setting up background map at line: 3072
# > Setting up background map at line: 3584
# > Setting up background map at line: 4096
# > Setting up background map at line: 4608
# > Setting up background map at line: 5120
# > Setting up background map at line: 5632
# > Setting up background map at line: 6144
# > Setting up background map at line: 6656
# > Setting up background map at line: 7168
# > Setting up background map at line: 7680
# > Setting up background map at line: 8192
# > Setting up background map at line: 8704
# > Setting up background map at line: 9216
# > Setting up background map at line: 9728
# > Setting up background map at line:10240
# > Setting up background map at line:10752
# > Filtering background map(s)
# > Computing background d-map
# > Computing background-noise d-map
# (M+D) Background: 2.01617e-08 RMS: 0.00754178 / Threshold: 0.0754178
# > Scanning image
# > Line:   25  Objects:        0 detected /        0 sextracted
# > Line:   50  Objects:        0 detected /        0 sextracted
# > Line:   75  Objects:        0 detected /        0 sextracted
# > Line:  100  Objects:        0 detected /        0 sextracted
# > Line:  125  Objects:        0 detected /        0 sextracted
# > Line:  150  Objects:        0 detected /        0 sextracted
# > Line:  175  Objects:        0 detected /        0 sextracted
# > Line:  200  Objects:        0 detected /        0 sextracted
# > Line:  225  Objects:        0 detected /        0 sextracted
# > Line:  250  Objects:        0 detected /        0 sextracted
# > Line:  275  Objects:        0 detected /        0 sextracted
# > Line:  300  Objects:        0 detected /        0 sextracted
# > Line:  325  Objects:        0 detected /        0 sextracted
# > Line:  350  Objects:        0 detected /        0 sextracted
# > Line:  375  Objects:        0 detected /        0 sextracted
# > Line:  400  Objects:        0 detected /        0 sextracted
# > Line:  425  Objects:        0 detected /        0 sextracted
# > Line:  450  Objects:        0 detected /        0 sextracted
# > Line:  475  Objects:        0 detected /        0 sextracted
# > Line:  500  Objects:        0 detected /        0 sextracted
# > Line:  525  Objects:        0 detected /        0 sextracted
# > Line:  550  Objects:        0 detected /        0 sextracted
# > Line:  575  Objects:        0 detected /        0 sextracted
# > Line:  600  Objects:        0 detected /        0 sextracted
# > Line:  625  Objects:        0 detected /        0 sextracted
# > Line:  650  Objects:        0 detected /        0 sextracted
# > Line:  675  Objects:        0 detected /        0 sextracted
# > Line:  700  Objects:        0 detected /        0 sextracted
# > Line:  725  Objects:        0 detected /        0 sextracted
# > Line:  750  Objects:        0 detected /        0 sextracted
# > Line:  775  Objects:        0 detected /        0 sextracted
# > Line:  800  Objects:        0 detected /        0 sextracted
# > Line:  825  Objects:        0 detected /        0 sextracted
# > Line:  850  Objects:        0 detected /        0 sextracted
# > Line:  875  Objects:        0 detected /        0 sextracted
# > Line:  900  Objects:        0 detected /        0 sextracted
# > Line:  925  Objects:        0 detected /        0 sextracted
# > Line:  950  Objects:        0 detected /        0 sextracted
# > Line:  975  Objects:        1 detected /        0 sextracted
# > Line: 1000  Objects:        1 detected /        0 sextracted
# > Line: 1025  Objects:        7 detected /        0 sextracted
# > Line: 1050  Objects:       14 detected /        0 sextracted
# > Line: 1075  Objects:       30 detected /        0 sextracted
# > Line: 1100  Objects:       44 detected /        0 sextracted
# > Line: 1125  Objects:       58 detected /        0 sextracted
# > Line: 1150  Objects:       67 detected /        0 sextracted
# > Line: 1175  Objects:       69 detected /        0 sextracted
# > Line: 1200  Objects:       78 detected /        0 sextracted
# > Line: 1225  Objects:       87 detected /        0 sextracted
# > Line: 1250  Objects:       93 detected /        0 sextracted
# > Line: 1275  Objects:      108 detected /        0 sextracted
# > Line: 1300  Objects:      119 detected /        0 sextracted
# > Line: 1325  Objects:      131 detected /        0 sextracted
# > Line: 1350  Objects:      149 detected /        0 sextracted
# > Line: 1375  Objects:      162 detected /        0 sextracted
# > Line: 1400  Objects:      176 detected /        0 sextracted
# > Line: 1425  Objects:      185 detected /        0 sextracted
# > Line: 1450  Objects:      192 detected /        0 sextracted
# > Line: 1475  Objects:      205 detected /        0 sextracted
# > Line: 1500  Objects:      215 detected /        0 sextracted
# > Line: 1525  Objects:      229 detected /        0 sextracted
# > Line: 1550  Objects:      239 detected /        0 sextracted
# > Line: 1575  Objects:      251 detected /        0 sextracted
# > Line: 1600  Objects:      261 detected /        0 sextracted
# > Line: 1625  Objects:      268 detected /        0 sextracted
# > Line: 1650  Objects:      278 detected /        0 sextracted
# > Line: 1675  Objects:      285 detected /        0 sextracted
# > Line: 1700  Objects:      292 detected /        0 sextracted
# > Line: 1725  Objects:      299 detected /        0 sextracted
# > Line: 1750  Objects:      309 detected /        0 sextracted
# > Line: 1775  Objects:      315 detected /        0 sextracted
# > Line: 1800  Objects:      321 detected /        0 sextracted
# > Line: 1825  Objects:      336 detected /        0 sextracted
# > Line: 1850  Objects:      348 detected /        0 sextracted
# > Line: 1875  Objects:      359 detected /        0 sextracted
# > Line: 1900  Objects:      366 detected /        0 sextracted
# > Line: 1925  Objects:      379 detected /        0 sextracted
# > Line: 1950  Objects:      387 detected /        0 sextracted
# > Line: 1975  Objects:      396 detected /        0 sextracted
# > Line: 2000  Objects:      411 detected /        0 sextracted
# > Line: 2025  Objects:      416 detected /        0 sextracted
# > Line: 2050  Objects:      433 detected /        0 sextracted
# > Line: 2075  Objects:      443 detected /        0 sextracted
# > Line: 2100  Objects:      452 detected /        0 sextracted
# > Line: 7650  Objects:     2570 detected /        0 sextracted
# > Line: 7675  Objects:     2583 detected /        0 sextracted
# > Line: 7700  Objects:     2597 detected /        0 sextracted
# > Line: 7725  Objects:     2606 detected /        0 sextracted
# > Line: 7750  Objects:     2614 detected /        0 sextracted
# > Line: 7775  Objects:     2628 detected /        0 sextracted
# > Line: 7800  Objects:     2639 detected /        0 sextracted
# > Line: 7825  Objects:     2647 detected /        0 sextracted
# > Line: 7850  Objects:     2658 detected /        0 sextracted
# > Line: 7875  Objects:     2668 detected /        0 sextracted
# > Line: 7900  Objects:     2679 detected /        0 sextracted
# > Line: 7925  Objects:     2684 detected /        0 sextracted
# > Line: 7950  Objects:     2689 detected /        0 sextracted
# > Line: 7975  Objects:     2701 detected /        0 sextracted
# > Line: 8000  Objects:     2709 detected /        0 sextracted
# > Line: 8025  Objects:     2720 detected /        0 sextracted
# > Line: 8050  Objects:     2726 detected /        0 sextracted
# > Line: 8075  Objects:     2733 detected /        0 sextracted
# > Line: 8100  Objects:     2741 detected /        0 sextracted
# > Line: 8125  Objects:     2750 detected /        0 sextracted
# > Line: 8150  Objects:     2755 detected /        0 sextracted
# > Line: 8175  Objects:     2763 detected /        0 sextracted
# > Line: 8200  Objects:     2773 detected /        0 sextracted
# > Line: 8225  Objects:     2783 detected /        0 sextracted
# > Line: 8250  Objects:     2787 detected /        0 sextracted
# > Line: 8275  Objects:     2799 detected /        0 sextracted
# > Line: 8300  Objects:     2811 detected /        0 sextracted
# > Line: 8325  Objects:     2819 detected /        0 sextracted
# > Line: 8350  Objects:     2825 detected /        0 sextracted
# > Line: 8375  Objects:     2836 detected /        0 sextracted
# > Line: 8400  Objects:     2848 detected /        0 sextracted
# > Line: 8425  Objects:     2861 detected /        0 sextracted
# > Line: 8450  Objects:     2875 detected /        0 sextracted
# > Line: 8475  Objects:     2886 detected /        0 sextracted
# > Line: 8500  Objects:     2891 detected /        0 sextracted
# > Line: 8525  Objects:     2897 detected /        0 sextracted
# > Line: 8550  Objects:     2906 detected /        0 sextracted
# > Line: 8575  Objects:     2919 detected /        0 sextracted
# > Line: 8600  Objects:     2926 detected /        0 sextracted
# > Line: 8625  Objects:     2937 detected /        0 sextracted
# > Line: 8650  Objects:     2944 detected /        0 sextracted
# > Line: 8675  Objects:     2955 detected /        0 sextracted
# > Line: 8700  Objects:     2965 detected /        0 sextracted
# > Line: 8725  Objects:     2978 detected /        0 sextracted
# > Line: 8750  Objects:     2987 detected /        0 sextracted
# > Line: 8775  Objects:     2997 detected /        0 sextracted
# > Line: 8800  Objects:     3012 detected /        0 sextracted
# > Line: 8825  Objects:     3031 detected /        0 sextracted
# > Line: 8850  Objects:     3045 detected /        0 sextracted
# > Line: 8875  Objects:     3053 detected /        0 sextracted
# > Line: 8900  Objects:     3062 detected /        0 sextracted
# > Line: 8925  Objects:     3067 detected /        0 sextracted
# > Line: 8950  Objects:     3078 detected /        0 sextracted
# > Line: 8975  Objects:     3085 detected /        0 sextracted
# > Line: 9000  Objects:     3090 detected /        0 sextracted
# > Line: 9025  Objects:     3100 detected /        0 sextracted
# > Line: 9050  Objects:     3113 detected /        0 sextracted
# > Line: 9075  Objects:     3123 detected /        0 sextracted
# > Line: 9100  Objects:     3128 detected /        0 sextracted
# > Line: 9125  Objects:     3142 detected /        0 sextracted
# > Line: 9150  Objects:     3152 detected /        0 sextracted
# > Line: 9175  Objects:     3160 detected /        0 sextracted
# > Line: 9200  Objects:     3172 detected /        0 sextracted
# > Line: 9225  Objects:     3182 detected /        0 sextracted
# > Line: 9250  Objects:     3192 detected /        0 sextracted
# > Line: 9275  Objects:     3206 detected /        0 sextracted
# > Line: 9300  Objects:     3213 detected /        0 sextracted
# > Line: 9325  Objects:     3221 detected /        0 sextracted
# > Line: 9350  Objects:     3232 detected /        0 sextracted
# > Line: 9375  Objects:     3239 detected /        0 sextracted
# > Line: 9400  Objects:     3246 detected /        0 sextracted
# > Line: 9425  Objects:     3255 detected /        0 sextracted
# > Line: 9450  Objects:     3266 detected /        0 sextracted
# > Line: 9475  Objects:     3274 detected /        0 sextracted
# > Line: 9500  Objects:     3282 detected /        0 sextracted
# > Line: 9525  Objects:     3295 detected /        0 sextracted
# > Line: 9550  Objects:     3308 detected /        0 sextracted
# > Line: 9575  Objects:     3321 detected /        0 sextracted
# > Line: 9600  Objects:     3333 detected /        0 sextracted
# > Line: 9625  Objects:     3341 detected /        0 sextracted
# > Line: 9650  Objects:     3348 detected /        0 sextracted
# > Line: 9675  Objects:     3360 detected /        0 sextracted
# > Line: 9700  Objects:     3372 detected /        0 sextracted
# > Line: 9725  Objects:     3382 detected /        0 sextracted
# > Line: 9750  Objects:     3392 detected /        0 sextracted
# > Line: 9775  Objects:     3404 detected /        0 sextracted
# > Line: 9800  Objects:     3410 detected /        0 sextracted
# > Line: 9825  Objects:     3417 detected /        0 sextracted
# > Line: 9850  Objects:     3429 detected /        0 sextracted
# > Line: 9875  Objects:     3443 detected /        0 sextracted
# > Line: 9900  Objects:     3460 detected /        0 sextracted
# > Line: 9925  Objects:     3470 detected /        0 sextracted
# > Line: 9950  Objects:     3480 detected /        0 sextracted
# > Line: 9975  Objects:     3492 detected /        0 sextracted
# > Line:10000  Objects:     3502 detected /        0 sextracted
# > Line:10025  Objects:     3515 detected /        0 sextracted
# > Line:10050  Objects:     3524 detected /        0 sextracted
# > Line:10075  Objects:     3535 detected /        0 sextracted
# > Line:10100  Objects:     3545 detected /        0 sextracted
# > Line:10125  Objects:     3555 detected /        0 sextracted
# > Line:10150  Objects:     3561 detected /        0 sextracted
# > Line:10175  Objects:     3570 detected /        0 sextracted
# > Line:10200  Objects:     3583 detected /        0 sextracted
# > Line:10225  Objects:     3596 detected /        0 sextracted
# > Line:10250  Objects:     3606 detected /        0 sextracted
# > Line:10275  Objects:     3613 detected /        0 sextracted
# > Line:10300  Objects:     3622 detected /        0 sextracted
# > Line:10325  Objects:     3626 detected /        0 sextracted
# > Line:10350  Objects:     3628 detected /        0 sextracted
# > Line:10375  Objects:     3628 detected /        0 sextracted
# > Line:10400  Objects:     3628 detected /        0 sextracted
# > Line:10425  Objects:     3628 detected /        0 sextracted
# > Line:10450  Objects:     3628 detected /        0 sextracted
# > Line:10475  Objects:     3628 detected /        0 sextracted
# > Line:10500  Objects:     3628 detected /        0 sextracted
# > Line:10525  Objects:     3628 detected /        0 sextracted
# > Line:10550  Objects:     3628 detected /        0 sextracted
# > Line:10575  Objects:     3628 detected /        0 sextracted
# > Line:10600  Objects:     3628 detected /        0 sextracted
# > Line:10625  Objects:     3628 detected /        0 sextracted
# > Line:10650  Objects:     3628 detected /        0 sextracted
# > Line:10675  Objects:     3628 detected /        0 sextracted
# > Line:10700  Objects:     3628 detected /        0 sextracted
# > Line:10725  Objects:     3628 detected /        0 sextracted
# > Line:10750  Objects:     3628 detected /        0 sextracted
# > Line:10775  Objects:     3628 detected /        0 sextracted
# > Line:10800  Objects:     3628 detected /        0 sextracted
# > Line:10825  Objects:     3628 detected /        0 sextracted
# > Line:10850  Objects:     3628 detected /        0 sextracted
# > Line:10875  Objects:     3628 detected /        0 sextracted
# > Line:10900  Objects:     3628 detected /        0 sextracted
# > Line:10925  Objects:     3628 detected /        0 sextracted
# > Line:10950  Objects:     3628 detected /        0 sextracted
# > Line:10975  Objects:     3628 detected /        0 sextracted
# > Line:11000  Objects:     3628 detected /        0 sextracted
# > Line:11000  Objects:     3628 detected /        0 sextracted
# > Line:11000  Objects:     3628 detected /      400 sextracted
# > Line:11000  Objects:     3628 detected /      800 sextracted
# > Line:11000  Objects:     3628 detected /     1200 sextracted
# > Line:11000  Objects:     3628 detected /     1600 sextracted
# > Line:11000  Objects:     3628 detected /     2000 sextracted
# > Line:11000  Objects:     3628 detected /     2400 sextracted
# > Line:11000  Objects:     3628 detected /     2800 sextracted
# > Line:11000  Objects:     3628 detected /     3200 sextracted
#       Objects: detected 3628     / sextracted 3591
#
# > Closing files
# >
# > All done (in 3.3 s: 3370.2 lines/s , 1100.2 detections/s)

# %%
psf = mar.wrappers.PSFex("outputs/final.test.fits")


psf.run()
# Out:
# > WARNING: This executable has been compiled using a version of the ATLAS library without support for multithreading. Performance will be degraded.
#
# >
# ----- PSFEx 3.23.0 started on 2023-02-07 at 17:06:29 with 12 threads
#
# >
# ----- 1 input catalogues:
# final.test.fits     :  "HYDRA_0111      "    1 extension     861 detections
#
# > Initializing contexts...
# > Computing optimum PSF sampling steps...
# > Reading data from final.test...
# > Computing final PSF model for final.test...
#    filename      [ext] accepted/total samp. chi2/dof FWHM ellip. resi. asym.
# > Computing diagnostics for final.test...
# final.test                 659/831     0.70   1.87   2.44  0.01  0.02  0.02
# > Saving PSF model and metadata for final.test...
# > Writing XML file...
# >
# > All done (in 0.0 s)

# %%
psf.getPSFinfo()
# Out:
# {'NStars_Loaded_Total': 831,
#  'NStars_Accepted_Total': 659,
#  'FWHM_Mean': 2.4359,
#  'FWHM_Min': 2.31162,
#  'FWHM_Max': 2.67902,
#  'Chi2_Mean': 1.87127,
#  'MoffatBeta_Mean': 2.57804,
#  'Asymmetry_Mean': 0.0151009,
#  'Ellipticity_Mean': 0.0147957}
